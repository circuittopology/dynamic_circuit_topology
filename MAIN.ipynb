# %% [markdown]
# # <center>Circuit Topology script V2.0</center>
#
# <center>Duane Moes - For suggestions and further questions: moesduane@gmail.com </center><br>
# <center>Github:   <a href="url" target="https://github.com/Duanetech/circuit_topology">github.com/Duanetech/circuit_topology</a></center>
#
#
# ---
# This is a fully automated script that mainly utilizes biopython to perform circuit topology analysis on a given set of proteins. When possible, try to use the mmCIF file system instead of the PDB file option, this is because PDB is outdated and more prone to missing atoms etc.This script serves as an example, you can always create your own loop and use the functions separately if you want to. See the README for installation help and documentation of the functions. If a new update comes out, use the download code option on the github page.
#
# #### Packages used
# <ul><li>BioPython</li>
#     <li>Pandas</li>
# <li>SciPy </li>
# <li>NumPy</li>
# <li>MatPlotlib</li>
# <li>DSSP</li>
# </ul>
#
#
#
# Run the code below to install all the needed dependencies (only once!).<br> Warning: This can take a while, if it has finished you can delete the code block.

# %%
# !conda env update --file requirements.yml

# %% [markdown]
# #### Importing
# These are import statements, you have to run this codeblock everytime you restart and/or quit Jupyter.

# %%
from functions.plots.circuit_plot import circuit_plot
from functions.plots.matrix_plot import matrix_plot
from functions.plots.stats_plot import stats_plot
from functions.plots.matrix_plot_model import matrix_plot_model

from functions.calculating.get_cmap import get_cmap
from functions.calculating.get_matrix import get_matrix
from functions.calculating.get_stats import get_stats
from functions.calculating.energy_cmap import energy_cmap
from functions.calculating.string_pdb import string_pdb
from functions.calculating.secondary_struc_cmap import secondary_struc_cmap
from functions.calculating.secondary_struc_filter import secondary_struc_filter
from functions.calculating.glob_score import glob_score
from functions.calculating.length_filter import length_filter

from functions.importing.retrieve_chain import retrieve_chain
from functions.importing.retrieve_cif import retrieve_cif
from functions.importing.retrieve_cif_list import retrieve_cif_list
from functions.importing.retrieve_secondary_struc import retrieve_secondary_struc
from functions.importing.stride_secondary_struc import stride_secondary_struc

from functions.exporting.export_psc import export_psc
from functions.exporting.export_cmap3 import export_cmap3
from functions.exporting.export_mat import export_mat
from functions.exporting.export_cmap4 import export_cmap4
from functions.exporting.export_circuit import export_circuit

from ipywidgets import widgets
import numpy as np 
import pandas as pd
import os
import matplotlib
# %matplotlib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\SCALVI~1\AppData\Local\Temp/ipykernel_13268/3616946947.py in <module>
# ----> 1 from functions.plots.circuit_plot import circuit_plot
#       2 from functions.plots.matrix_plot import matrix_plot
#       3 from functions.plots.stats_plot import stats_plot
#       4 from functions.plots.matrix_plot_model import matrix_plot_model
#       5
#
# ModuleNotFoundError: No module named 'functions.plots'

# %% [markdown]
# ## <center> User guide </center>
# <ul>
#     <li>Either copy your <code>.PDB</code> or <code>.CIF </code> files to their respective maps in <code>/input_files/</code>, or use the retrieve CIF function to download them.
# </li>
# </ul>
#
# #### Retrieving CIF files
# These Functions will automatically download the specified mmCIF files from RCSB PDB to their respective maps in <code>/input_files/</code>. <br>
#
# <i>NOTE that when using a large number of proteins (>50), it is more efficient to use the batch download function from the <a href="url" target="https://www.rcsb.org/downloads">RCSB Db</a> </i><br>
#
# * Use the following function to download a single mmCif file by entering the protein ID <br>

# %%
retrieve_cif('1bni')
# Out:
# Downloading PDB structure '1bni'...

# %% [markdown]
# * The following function Downloads all of the mmCIF files specified in <code>input_files/protlist.txt</code>

# %%
retrieve_cif_list()
# Out:
# Downloading PDB structure '4chj'...
# Downloading PDB structure '1a6n'...

# %% [markdown]
#
# ####  ***Variable input***
# These are variables used for the **Main** script. <br> It is also possible to create your own loop and see the README manual for all the functions.
#
# <ul>
# <li><code>fileformat</code> Preferred filetype, CIF is recommendend because of a possibility of missing atoms occuring in PDB files. <br></li>
#
#   <br>
# <li><code>cutoff_distance</code>, maximal distance (Ångström) between two atoms that will count as an atom-atom contact.<br> </li>
# <li><code>cutoff_numcontacts</code>, minimum number of contacts between two residues to count as a res-res contact. <br></li>
# <li><code>exclude_neighbour</code>, number of neighbours that are excluded from possbile res-res contacts. <br></li>
#     <br>
# <li><code>length_filtering</code> (0/1), activates length filtering.
# <li><code>filtering_distance</code>, specify which max/min distance you want to use.
# <li><code>length_mode</code> specifies whether you want short range filtering or long range filtering.
#     <br>
#     <br>
# <li><code>energy_filtering</code>(0/1), activates energy filtering.</li>
#  <li><code>energy_filtering_mode</code>(+/-), sets the energy filtering mode.</li>
# <br>
# <li><code>plot_figures</code>(0/1),Plots figures when activated. Would not recommend with large amound of files.</li>
# <li><code>export_psc</code>(0/1), exporting the resulting PSC stats to a txt file located in <code>results/statistics/psc</code>       (Overwrites a previous created file)</li>
# <li><code>export_cmap3</code>(0/1), exporting the Residue contact map to a csv file located in <code>results/circuit_diagram</code></li>
# <li><code>export_mat</code>(0/1), exporting the topology relations matrix to a csv file located in <code>results/matrix</code></li>
# </ul>

# %%
# Format
fileformat =            'pdb'

# CT variables
cutoff_distance =       4.5
cutoff_numcontacts =    5
exclude_neighbour =     3

#Length Filtering
length_filtering =      0
filtering_distance =    0
length_mode =           '<'

#Energy filtering
energy_filtering =      0
energy_filtering_mode = '+'

#Time filtering (requires a time filter)
time_filtering = 0

# Exporting
plot_figures =          0
exporting_psc =         1
exporting_cmap3 =       1
exporting_mat   =       0

# %% [markdown]
# #### <center>MAIN</center>
# -------

# %% [markdown]
# ##### Single file

# %%
#Creates a chain object from a CIF/PDB file
chain,protid = retrieve_chain('1pnj.pdb')

#Step 1 - Draw a residue-residue based contact map 
index,numbering,protid,res_names = get_cmap(
                                            chain,
                                            cutoff_distance = cutoff_distance,
                                            cutoff_numcontacts = cutoff_numcontacts,        
                                            exclude_neighbour = exclude_neighbour)

#Step 3 - Draw a circuit topology relations matrix
mat, psc = get_matrix(index,protid)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-bafa2795cc3e> in <module>
#       1 #Creates a chain object from a CIF/PDB file
# ----> 2 chain,protid = retrieve_chain('1pnj.pdb')
#       3
#       4 #Step 1 - Draw a residue-residue based contact map
#       5 index,numbering,protid,res_names = get_cmap(
#
# ~\Documents\Phd_project_reduced\work directory jupyter lab\dynamic CT\circuit_topology\functions\importing\retrieve_chain.py in retrieve_chain(input_file, chainid)
#      28             input_filepath= 'input_files/pdb/' + input_file
#      29
# ---> 30             structure = PDBParser(PERMISSIVE=1).get_structure(input_file.replace('.pdb',''),input_filepath)
#      31
#      32     model = structure[0]
#
# ~\Anaconda3\envs\data_analysis\lib\site-packages\Bio\PDB\PDBParser.py in get_structure(self, id, file)
#      94             self.structure_builder.init_structure(id)
#      95
# ---> 96             with as_handle(file) as handle:
#      97                 lines = handle.readlines()
#      98                 if not lines:
#
# ~\Anaconda3\envs\data_analysis\lib\contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~\Anaconda3\envs\data_analysis\lib\site-packages\Bio\File.py in as_handle(handleish, mode, **kwargs)
#      70     """
#      71     try:
# ---> 72         with open(handleish, mode, **kwargs) as fp:
#      73             yield fp
#      74     except TypeError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'input_files/pdb/1pnj.pdb'

# %%
cmap_filter= pd.read_csv('masks/AR/middle_map_run3.csv', header=None)
cmap_filter=np.array(cmap_filter)
cmap_filter.shape
# Out:
# (538, 538)

# %% [markdown]
# ##### Multiple files

# %%
number_of_files = len(os.listdir('input_files/' +fileformat))

psclist = []

for num,files in enumerate(os.listdir('input_files/' +fileformat)):
    if files.endswith(('cif','pdb')):
  
        try:
            #Creates a chain object from a CIF/PDB file
            chain,protid = retrieve_chain(files)
            print(f'{files} - {num+1}/{number_of_files}')
            
        except Exception as e:
            
            print(f'{files} - {e}')
            continue
    else:
        continue
        
    #Step 1 - Draw a residue-residue based contact map 
    index,numbering,protid,res_names = get_cmap(
                                                chain,
                                                cutoff_distance = cutoff_distance,
                                                cutoff_numcontacts = cutoff_numcontacts,        
                                                exclude_neighbour = exclude_neighbour)
    
    #Step 1.5 - Energy filtering
    if energy_filtering:
        index,protid = energy_cmap(index,numbering,
                               res_names,protid,
                               energy_filtering_mode)    
        
    #Step 2 - Lenght filtering
    if length_filtering:
        index = length_filter(index,
                              filtering_distance,
                              length_mode)
        
    if time_filtering:
        cmap_mat = np.zeros([len(numbering),len(numbering)],dtype='int')

        for row in index:
            x = row[0]
            y = row[1]
            cmap_mat[x][y] = 1
            cmap_mat= cmap_mat*cmap_filter
        index=np.array(np.nonzero(cmap_mat))
        index=np.transpose(index)
        
        
    #Step 3 - Draw a circuit topology relations matrix
    mat, psc = get_matrix(index,protid)
    psclist.append(psc)
    
    #Step 4 - Circuit topology statistics
    entangled = get_stats(mat)
    
    #Plotting
    if plot_figures:
        circuit_plot(index,protid,numbering)
        matrix_plot(mat,protid)
        stats_plot(entangled,psc,protid)
    
    #Exporting    
    if exporting_cmap3:
        export_cmap3(index,protid,numbering)
        
    if exporting_mat:
        export_mat(index,mat,protid)
        
if exporting_psc:
    export_psc(psclist)
# Out:
# x0000.pdb - 1/1000
# Succesfully saved x0000_ _cmap3.csv
# x0001.pdb - 2/1000
# Succesfully saved x0001_ _cmap3.csv
# x0002.pdb - 3/1000
# Succesfully saved x0002_ _cmap3.csv
# x0003.pdb - 4/1000
# Succesfully saved x0003_ _cmap3.csv
# x0004.pdb - 5/1000
# Succesfully saved x0004_ _cmap3.csv
# x0005.pdb - 6/1000
# Succesfully saved x0005_ _cmap3.csv
# x0006.pdb - 7/1000
# Succesfully saved x0006_ _cmap3.csv
# x0007.pdb - 8/1000
# Succesfully saved x0007_ _cmap3.csv
# x0008.pdb - 9/1000
# Succesfully saved x0008_ _cmap3.csv
# x0009.pdb - 10/1000
# Succesfully saved x0009_ _cmap3.csv
# x0010.pdb - 11/1000
# Succesfully saved x0010_ _cmap3.csv
# x0011.pdb - 12/1000
# Succesfully saved x0011_ _cmap3.csv
# x0012.pdb - 13/1000
# Succesfully saved x0012_ _cmap3.csv
# x0013.pdb - 14/1000
# Succesfully saved x0013_ _cmap3.csv
# x0014.pdb - 15/1000
# Succesfully saved x0014_ _cmap3.csv
# x0015.pdb - 16/1000
# Succesfully saved x0015_ _cmap3.csv
# x0016.pdb - 17/1000
# Succesfully saved x0016_ _cmap3.csv
# x0017.pdb - 18/1000
# Succesfully saved x0017_ _cmap3.csv
# x0018.pdb - 19/1000
# Succesfully saved x0018_ _cmap3.csv
# x0019.pdb - 20/1000
# Succesfully saved x0019_ _cmap3.csv
# x0020.pdb - 21/1000
# Succesfully saved x0020_ _cmap3.csv
# x0021.pdb - 22/1000
# Succesfully saved x0021_ _cmap3.csv
# x0022.pdb - 23/1000
# Succesfully saved x0022_ _cmap3.csv
# x0023.pdb - 24/1000
# Succesfully saved x0023_ _cmap3.csv
# x0024.pdb - 25/1000
# Succesfully saved x0024_ _cmap3.csv
# x0025.pdb - 26/1000
# Succesfully saved x0025_ _cmap3.csv
# x0026.pdb - 27/1000
# Succesfully saved x0026_ _cmap3.csv
# x0027.pdb - 28/1000
# Succesfully saved x0027_ _cmap3.csv
# x0028.pdb - 29/1000
# Succesfully saved x0028_ _cmap3.csv
# x0029.pdb - 30/1000
# Succesfully saved x0029_ _cmap3.csv
# x0030.pdb - 31/1000
# Succesfully saved x0030_ _cmap3.csv
# x0031.pdb - 32/1000
# Succesfully saved x0031_ _cmap3.csv
# x0032.pdb - 33/1000
# Succesfully saved x0032_ _cmap3.csv
# x0033.pdb - 34/1000
# Succesfully saved x0033_ _cmap3.csv
# x0034.pdb - 35/1000
# Succesfully saved x0034_ _cmap3.csv
# x0035.pdb - 36/1000
# Succesfully saved x0035_ _cmap3.csv
# x0036.pdb - 37/1000
# Succesfully saved x0036_ _cmap3.csv
# x0037.pdb - 38/1000
# Succesfully saved x0037_ _cmap3.csv
# x0038.pdb - 39/1000
# Succesfully saved x0038_ _cmap3.csv
# x0039.pdb - 40/1000
# Succesfully saved x0039_ _cmap3.csv
# x0040.pdb - 41/1000
# Succesfully saved x0040_ _cmap3.csv
# x0041.pdb - 42/1000
# Succesfully saved x0041_ _cmap3.csv
# x0042.pdb - 43/1000
# Succesfully saved x0042_ _cmap3.csv
# x0043.pdb - 44/1000
# Succesfully saved x0043_ _cmap3.csv
# x0044.pdb - 45/1000
# Succesfully saved x0044_ _cmap3.csv
# x0045.pdb - 46/1000
# Succesfully saved x0045_ _cmap3.csv
# x0046.pdb - 47/1000
# Succesfully saved x0046_ _cmap3.csv
# x0047.pdb - 48/1000
# Succesfully saved x0047_ _cmap3.csv
# x0048.pdb - 49/1000
# Succesfully saved x0048_ _cmap3.csv
# x0049.pdb - 50/1000
# Succesfully saved x0049_ _cmap3.csv
# x0050.pdb - 51/1000
# Succesfully saved x0050_ _cmap3.csv
# x0051.pdb - 52/1000
# Succesfully saved x0051_ _cmap3.csv
# x0052.pdb - 53/1000
# Succesfully saved x0052_ _cmap3.csv
# x0053.pdb - 54/1000
# Succesfully saved x0053_ _cmap3.csv
# x0054.pdb - 55/1000
# Succesfully saved x0054_ _cmap3.csv
# x0055.pdb - 56/1000
# Succesfully saved x0055_ _cmap3.csv
# x0056.pdb - 57/1000
# Succesfully saved x0056_ _cmap3.csv
# x0057.pdb - 58/1000
# Succesfully saved x0057_ _cmap3.csv
# x0058.pdb - 59/1000
# Succesfully saved x0058_ _cmap3.csv
# x0059.pdb - 60/1000
# Succesfully saved x0059_ _cmap3.csv
# x0060.pdb - 61/1000
# Succesfully saved x0060_ _cmap3.csv
# x0061.pdb - 62/1000
# Succesfully saved x0061_ _cmap3.csv
# x0062.pdb - 63/1000
# Succesfully saved x0062_ _cmap3.csv
# x0063.pdb - 64/1000
# Succesfully saved x0063_ _cmap3.csv
# x0064.pdb - 65/1000
# Succesfully saved x0064_ _cmap3.csv
# x0065.pdb - 66/1000
# Succesfully saved x0065_ _cmap3.csv
# x0066.pdb - 67/1000
# Succesfully saved x0066_ _cmap3.csv
# x0067.pdb - 68/1000
# Succesfully saved x0067_ _cmap3.csv
# x0068.pdb - 69/1000
# Succesfully saved x0068_ _cmap3.csv
# x0069.pdb - 70/1000
# Succesfully saved x0069_ _cmap3.csv
# x0070.pdb - 71/1000
# Succesfully saved x0070_ _cmap3.csv
# x0071.pdb - 72/1000
# Succesfully saved x0071_ _cmap3.csv
# x0072.pdb - 73/1000
# Succesfully saved x0072_ _cmap3.csv
# x0073.pdb - 74/1000
# Succesfully saved x0073_ _cmap3.csv
# x0074.pdb - 75/1000
# Succesfully saved x0074_ _cmap3.csv
# x0075.pdb - 76/1000
# Succesfully saved x0075_ _cmap3.csv
# x0076.pdb - 77/1000
# Succesfully saved x0076_ _cmap3.csv
# x0077.pdb - 78/1000
# Succesfully saved x0077_ _cmap3.csv
# x0078.pdb - 79/1000
# Succesfully saved x0078_ _cmap3.csv
# x0079.pdb - 80/1000
# Succesfully saved x0079_ _cmap3.csv
# x0080.pdb - 81/1000
# Succesfully saved x0080_ _cmap3.csv
# x0081.pdb - 82/1000
# Succesfully saved x0081_ _cmap3.csv
# x0082.pdb - 83/1000
# Succesfully saved x0082_ _cmap3.csv
# x0083.pdb - 84/1000
# Succesfully saved x0083_ _cmap3.csv
# x0084.pdb - 85/1000
# Succesfully saved x0084_ _cmap3.csv
# x0085.pdb - 86/1000
# Succesfully saved x0085_ _cmap3.csv
# x0086.pdb - 87/1000
# Succesfully saved x0086_ _cmap3.csv
# x0087.pdb - 88/1000
# Succesfully saved x0087_ _cmap3.csv
# x0088.pdb - 89/1000
# Succesfully saved x0088_ _cmap3.csv
# x0089.pdb - 90/1000
# Succesfully saved x0089_ _cmap3.csv
# x0090.pdb - 91/1000
# Succesfully saved x0090_ _cmap3.csv
# x0091.pdb - 92/1000
# Succesfully saved x0091_ _cmap3.csv
# x0092.pdb - 93/1000
# Succesfully saved x0092_ _cmap3.csv
# x0093.pdb - 94/1000
# Succesfully saved x0093_ _cmap3.csv
# x0094.pdb - 95/1000
# Succesfully saved x0094_ _cmap3.csv
# x0095.pdb - 96/1000
# Succesfully saved x0095_ _cmap3.csv
# x0096.pdb - 97/1000
# Succesfully saved x0096_ _cmap3.csv
# x0097.pdb - 98/1000
# Succesfully saved x0097_ _cmap3.csv
# x0098.pdb - 99/1000
# Succesfully saved x0098_ _cmap3.csv
# x0099.pdb - 100/1000
# Succesfully saved x0099_ _cmap3.csv
# x0100.pdb - 101/1000
# Succesfully saved x0100_ _cmap3.csv
# x0101.pdb - 102/1000
# Succesfully saved x0101_ _cmap3.csv
# x0102.pdb - 103/1000
# Succesfully saved x0102_ _cmap3.csv
# x0103.pdb - 104/1000
# Succesfully saved x0103_ _cmap3.csv
# x0104.pdb - 105/1000
# Succesfully saved x0104_ _cmap3.csv
# x0105.pdb - 106/1000
# Succesfully saved x0105_ _cmap3.csv
# x0106.pdb - 107/1000
# Succesfully saved x0106_ _cmap3.csv
# x0107.pdb - 108/1000
# Succesfully saved x0107_ _cmap3.csv
# x0108.pdb - 109/1000
# Succesfully saved x0108_ _cmap3.csv
# x0109.pdb - 110/1000
# Succesfully saved x0109_ _cmap3.csv
# x0110.pdb - 111/1000
# Succesfully saved x0110_ _cmap3.csv
# x0111.pdb - 112/1000
# Succesfully saved x0111_ _cmap3.csv
# x0112.pdb - 113/1000
# Succesfully saved x0112_ _cmap3.csv
# x0113.pdb - 114/1000
# Succesfully saved x0113_ _cmap3.csv
# x0114.pdb - 115/1000
# Succesfully saved x0114_ _cmap3.csv
# x0115.pdb - 116/1000
# Succesfully saved x0115_ _cmap3.csv
# x0116.pdb - 117/1000
# Succesfully saved x0116_ _cmap3.csv
# x0117.pdb - 118/1000
# Succesfully saved x0117_ _cmap3.csv
# x0118.pdb - 119/1000
# Succesfully saved x0118_ _cmap3.csv
# x0119.pdb - 120/1000
# Succesfully saved x0119_ _cmap3.csv
# x0120.pdb - 121/1000
# Succesfully saved x0120_ _cmap3.csv
# x0121.pdb - 122/1000
# Succesfully saved x0121_ _cmap3.csv
# x0122.pdb - 123/1000
# Succesfully saved x0122_ _cmap3.csv
# x0123.pdb - 124/1000
# Succesfully saved x0123_ _cmap3.csv
# x0124.pdb - 125/1000
# Succesfully saved x0124_ _cmap3.csv
# x0125.pdb - 126/1000
# Succesfully saved x0125_ _cmap3.csv
# x0126.pdb - 127/1000
# Succesfully saved x0126_ _cmap3.csv
# x0127.pdb - 128/1000
# Succesfully saved x0127_ _cmap3.csv
# x0128.pdb - 129/1000
# Succesfully saved x0128_ _cmap3.csv
# x0129.pdb - 130/1000
# Succesfully saved x0129_ _cmap3.csv
# x0130.pdb - 131/1000
# Succesfully saved x0130_ _cmap3.csv
# x0131.pdb - 132/1000
# Succesfully saved x0131_ _cmap3.csv
# x0132.pdb - 133/1000
# Succesfully saved x0132_ _cmap3.csv
# x0133.pdb - 134/1000
# Succesfully saved x0133_ _cmap3.csv
# x0134.pdb - 135/1000
# Succesfully saved x0134_ _cmap3.csv
# x0135.pdb - 136/1000
# Succesfully saved x0135_ _cmap3.csv
# x0136.pdb - 137/1000
# Succesfully saved x0136_ _cmap3.csv
# x0137.pdb - 138/1000
# Succesfully saved x0137_ _cmap3.csv
# x0138.pdb - 139/1000
# Succesfully saved x0138_ _cmap3.csv
# x0139.pdb - 140/1000
# Succesfully saved x0139_ _cmap3.csv
# x0140.pdb - 141/1000
# Succesfully saved x0140_ _cmap3.csv
# x0141.pdb - 142/1000
# Succesfully saved x0141_ _cmap3.csv
# x0142.pdb - 143/1000
# Succesfully saved x0142_ _cmap3.csv
# x0143.pdb - 144/1000
# Succesfully saved x0143_ _cmap3.csv
# x0144.pdb - 145/1000
# Succesfully saved x0144_ _cmap3.csv
# x0145.pdb - 146/1000
# Succesfully saved x0145_ _cmap3.csv
# x0146.pdb - 147/1000
# Succesfully saved x0146_ _cmap3.csv
# x0147.pdb - 148/1000
# Succesfully saved x0147_ _cmap3.csv
# x0148.pdb - 149/1000
# Succesfully saved x0148_ _cmap3.csv
# x0149.pdb - 150/1000
# Succesfully saved x0149_ _cmap3.csv
# x0150.pdb - 151/1000
# Succesfully saved x0150_ _cmap3.csv
# x0151.pdb - 152/1000
# Succesfully saved x0151_ _cmap3.csv
# x0152.pdb - 153/1000
# Succesfully saved x0152_ _cmap3.csv
# x0153.pdb - 154/1000
# Succesfully saved x0153_ _cmap3.csv
# x0154.pdb - 155/1000
# Succesfully saved x0154_ _cmap3.csv
# x0155.pdb - 156/1000
# Succesfully saved x0155_ _cmap3.csv
# x0156.pdb - 157/1000
# Succesfully saved x0156_ _cmap3.csv
# x0157.pdb - 158/1000
# Succesfully saved x0157_ _cmap3.csv
# x0158.pdb - 159/1000
# Succesfully saved x0158_ _cmap3.csv
# x0159.pdb - 160/1000
# Succesfully saved x0159_ _cmap3.csv
# x0160.pdb - 161/1000
# Succesfully saved x0160_ _cmap3.csv
# x0161.pdb - 162/1000
# Succesfully saved x0161_ _cmap3.csv
# x0162.pdb - 163/1000
# Succesfully saved x0162_ _cmap3.csv
# x0163.pdb - 164/1000
# Succesfully saved x0163_ _cmap3.csv
# x0164.pdb - 165/1000
# Succesfully saved x0164_ _cmap3.csv
# x0165.pdb - 166/1000
# Succesfully saved x0165_ _cmap3.csv
# x0166.pdb - 167/1000
# Succesfully saved x0166_ _cmap3.csv
# x0167.pdb - 168/1000
# Succesfully saved x0167_ _cmap3.csv
# x0168.pdb - 169/1000
# Succesfully saved x0168_ _cmap3.csv
# x0169.pdb - 170/1000
# Succesfully saved x0169_ _cmap3.csv
# x0170.pdb - 171/1000
# Succesfully saved x0170_ _cmap3.csv
# x0171.pdb - 172/1000
# Succesfully saved x0171_ _cmap3.csv
# x0172.pdb - 173/1000
# Succesfully saved x0172_ _cmap3.csv
# x0173.pdb - 174/1000
# Succesfully saved x0173_ _cmap3.csv
# x0174.pdb - 175/1000
# Succesfully saved x0174_ _cmap3.csv
# x0175.pdb - 176/1000
# Succesfully saved x0175_ _cmap3.csv
# x0176.pdb - 177/1000
# Succesfully saved x0176_ _cmap3.csv
# x0177.pdb - 178/1000
# Succesfully saved x0177_ _cmap3.csv
# x0178.pdb - 179/1000
# Succesfully saved x0178_ _cmap3.csv
# x0179.pdb - 180/1000
# Succesfully saved x0179_ _cmap3.csv
# x0180.pdb - 181/1000
# Succesfully saved x0180_ _cmap3.csv
# x0181.pdb - 182/1000
# Succesfully saved x0181_ _cmap3.csv
# x0182.pdb - 183/1000
# Succesfully saved x0182_ _cmap3.csv
# x0183.pdb - 184/1000
# Succesfully saved x0183_ _cmap3.csv
# x0184.pdb - 185/1000
# Succesfully saved x0184_ _cmap3.csv
# x0185.pdb - 186/1000
# Succesfully saved x0185_ _cmap3.csv
# x0186.pdb - 187/1000
# Succesfully saved x0186_ _cmap3.csv
# x0187.pdb - 188/1000
# Succesfully saved x0187_ _cmap3.csv
# x0188.pdb - 189/1000
# Succesfully saved x0188_ _cmap3.csv
# x0189.pdb - 190/1000
# Succesfully saved x0189_ _cmap3.csv
# x0190.pdb - 191/1000
# Succesfully saved x0190_ _cmap3.csv
# x0191.pdb - 192/1000
# Succesfully saved x0191_ _cmap3.csv
# x0192.pdb - 193/1000
# Succesfully saved x0192_ _cmap3.csv
# x0193.pdb - 194/1000
# Succesfully saved x0193_ _cmap3.csv
# x0194.pdb - 195/1000
# Succesfully saved x0194_ _cmap3.csv
# x0195.pdb - 196/1000
# Succesfully saved x0195_ _cmap3.csv
# x0196.pdb - 197/1000
# Succesfully saved x0196_ _cmap3.csv
# x0197.pdb - 198/1000
# Succesfully saved x0197_ _cmap3.csv
# x0198.pdb - 199/1000
# Succesfully saved x0198_ _cmap3.csv
# x0199.pdb - 200/1000
# Succesfully saved x0199_ _cmap3.csv
# x0200.pdb - 201/1000
# Succesfully saved x0200_ _cmap3.csv
# x0201.pdb - 202/1000
# Succesfully saved x0201_ _cmap3.csv
# x0202.pdb - 203/1000
# Succesfully saved x0202_ _cmap3.csv
# x0203.pdb - 204/1000
# Succesfully saved x0203_ _cmap3.csv
# x0204.pdb - 205/1000
# Succesfully saved x0204_ _cmap3.csv
# x0205.pdb - 206/1000
# Succesfully saved x0205_ _cmap3.csv
# x0206.pdb - 207/1000
# Succesfully saved x0206_ _cmap3.csv
# x0207.pdb - 208/1000
# Succesfully saved x0207_ _cmap3.csv
# x0208.pdb - 209/1000
# Succesfully saved x0208_ _cmap3.csv
# x0209.pdb - 210/1000
# Succesfully saved x0209_ _cmap3.csv
# x0210.pdb - 211/1000
# Succesfully saved x0210_ _cmap3.csv
# x0211.pdb - 212/1000
# Succesfully saved x0211_ _cmap3.csv
# x0212.pdb - 213/1000
# Succesfully saved x0212_ _cmap3.csv
# x0213.pdb - 214/1000
# Succesfully saved x0213_ _cmap3.csv
# x0214.pdb - 215/1000
# Succesfully saved x0214_ _cmap3.csv
# x0215.pdb - 216/1000
# Succesfully saved x0215_ _cmap3.csv
# x0216.pdb - 217/1000
# Succesfully saved x0216_ _cmap3.csv
# x0217.pdb - 218/1000
# Succesfully saved x0217_ _cmap3.csv
# x0218.pdb - 219/1000
# Succesfully saved x0218_ _cmap3.csv
# x0219.pdb - 220/1000
# Succesfully saved x0219_ _cmap3.csv
# x0220.pdb - 221/1000
# Succesfully saved x0220_ _cmap3.csv
# x0221.pdb - 222/1000
# Succesfully saved x0221_ _cmap3.csv
# x0222.pdb - 223/1000
# Succesfully saved x0222_ _cmap3.csv
# x0223.pdb - 224/1000
# Succesfully saved x0223_ _cmap3.csv
# x0224.pdb - 225/1000
# Succesfully saved x0224_ _cmap3.csv
# x0225.pdb - 226/1000
# Succesfully saved x0225_ _cmap3.csv
# x0226.pdb - 227/1000
# Succesfully saved x0226_ _cmap3.csv
# x0227.pdb - 228/1000
# Succesfully saved x0227_ _cmap3.csv
# x0228.pdb - 229/1000
# Succesfully saved x0228_ _cmap3.csv
# x0229.pdb - 230/1000
# Succesfully saved x0229_ _cmap3.csv
# x0230.pdb - 231/1000
# Succesfully saved x0230_ _cmap3.csv
# x0231.pdb - 232/1000
# Succesfully saved x0231_ _cmap3.csv
# x0232.pdb - 233/1000
# Succesfully saved x0232_ _cmap3.csv
# x0233.pdb - 234/1000
# Succesfully saved x0233_ _cmap3.csv
# x0234.pdb - 235/1000
# Succesfully saved x0234_ _cmap3.csv
# x0235.pdb - 236/1000
# Succesfully saved x0235_ _cmap3.csv
# x0236.pdb - 237/1000
# Succesfully saved x0236_ _cmap3.csv
# x0237.pdb - 238/1000
# Succesfully saved x0237_ _cmap3.csv
# x0238.pdb - 239/1000
# Succesfully saved x0238_ _cmap3.csv
# x0239.pdb - 240/1000
# Succesfully saved x0239_ _cmap3.csv
# x0240.pdb - 241/1000
# Succesfully saved x0240_ _cmap3.csv
# x0241.pdb - 242/1000
# Succesfully saved x0241_ _cmap3.csv
# x0242.pdb - 243/1000
# Succesfully saved x0242_ _cmap3.csv
# x0243.pdb - 244/1000
# Succesfully saved x0243_ _cmap3.csv
# x0244.pdb - 245/1000
# Succesfully saved x0244_ _cmap3.csv
# x0245.pdb - 246/1000
# Succesfully saved x0245_ _cmap3.csv
# x0246.pdb - 247/1000
# Succesfully saved x0246_ _cmap3.csv
# x0247.pdb - 248/1000
# Succesfully saved x0247_ _cmap3.csv
# x0248.pdb - 249/1000
# Succesfully saved x0248_ _cmap3.csv
# x0249.pdb - 250/1000
# Succesfully saved x0249_ _cmap3.csv
# x0250.pdb - 251/1000
# Succesfully saved x0250_ _cmap3.csv
# x0251.pdb - 252/1000
# Succesfully saved x0251_ _cmap3.csv
# x0252.pdb - 253/1000
# Succesfully saved x0252_ _cmap3.csv
# x0253.pdb - 254/1000
# Succesfully saved x0253_ _cmap3.csv
# x0254.pdb - 255/1000
# Succesfully saved x0254_ _cmap3.csv
# x0255.pdb - 256/1000
# Succesfully saved x0255_ _cmap3.csv
# x0256.pdb - 257/1000
# Succesfully saved x0256_ _cmap3.csv
# x0257.pdb - 258/1000
# Succesfully saved x0257_ _cmap3.csv
# x0258.pdb - 259/1000
# Succesfully saved x0258_ _cmap3.csv
# x0259.pdb - 260/1000
# Succesfully saved x0259_ _cmap3.csv
# x0260.pdb - 261/1000
# Succesfully saved x0260_ _cmap3.csv
# x0261.pdb - 262/1000
# Succesfully saved x0261_ _cmap3.csv
# x0262.pdb - 263/1000
# Succesfully saved x0262_ _cmap3.csv
# x0263.pdb - 264/1000
# Succesfully saved x0263_ _cmap3.csv
# x0264.pdb - 265/1000
# Succesfully saved x0264_ _cmap3.csv
# x0265.pdb - 266/1000
# Succesfully saved x0265_ _cmap3.csv
# x0266.pdb - 267/1000
# Succesfully saved x0266_ _cmap3.csv
# x0267.pdb - 268/1000
# Succesfully saved x0267_ _cmap3.csv
# x0268.pdb - 269/1000
# Succesfully saved x0268_ _cmap3.csv
# x0269.pdb - 270/1000
# Succesfully saved x0269_ _cmap3.csv
# x0270.pdb - 271/1000
# Succesfully saved x0270_ _cmap3.csv
# x0271.pdb - 272/1000
# Succesfully saved x0271_ _cmap3.csv
# x0272.pdb - 273/1000
# Succesfully saved x0272_ _cmap3.csv
# x0273.pdb - 274/1000
# Succesfully saved x0273_ _cmap3.csv
# x0274.pdb - 275/1000
# Succesfully saved x0274_ _cmap3.csv
# x0275.pdb - 276/1000
# Succesfully saved x0275_ _cmap3.csv
# x0276.pdb - 277/1000
# Succesfully saved x0276_ _cmap3.csv
# x0277.pdb - 278/1000
# Succesfully saved x0277_ _cmap3.csv
# x0278.pdb - 279/1000
# Succesfully saved x0278_ _cmap3.csv
# x0279.pdb - 280/1000
# Succesfully saved x0279_ _cmap3.csv
# x0280.pdb - 281/1000
# Succesfully saved x0280_ _cmap3.csv
# x0281.pdb - 282/1000
# Succesfully saved x0281_ _cmap3.csv
# x0282.pdb - 283/1000
# Succesfully saved x0282_ _cmap3.csv
# x0283.pdb - 284/1000
# Succesfully saved x0283_ _cmap3.csv
# x0284.pdb - 285/1000
# Succesfully saved x0284_ _cmap3.csv
# x0285.pdb - 286/1000
# Succesfully saved x0285_ _cmap3.csv
# x0286.pdb - 287/1000
# Succesfully saved x0286_ _cmap3.csv
# x0287.pdb - 288/1000
# Succesfully saved x0287_ _cmap3.csv
# x0288.pdb - 289/1000
# Succesfully saved x0288_ _cmap3.csv
# x0289.pdb - 290/1000
# Succesfully saved x0289_ _cmap3.csv
# x0290.pdb - 291/1000
# Succesfully saved x0290_ _cmap3.csv
# x0291.pdb - 292/1000
# Succesfully saved x0291_ _cmap3.csv
# x0292.pdb - 293/1000
# Succesfully saved x0292_ _cmap3.csv
# x0293.pdb - 294/1000
# Succesfully saved x0293_ _cmap3.csv
# x0294.pdb - 295/1000
# Succesfully saved x0294_ _cmap3.csv
# x0295.pdb - 296/1000
# Succesfully saved x0295_ _cmap3.csv
# x0296.pdb - 297/1000
# Succesfully saved x0296_ _cmap3.csv
# x0297.pdb - 298/1000
# Succesfully saved x0297_ _cmap3.csv
# x0298.pdb - 299/1000
# Succesfully saved x0298_ _cmap3.csv
# x0299.pdb - 300/1000
# Succesfully saved x0299_ _cmap3.csv
# x0300.pdb - 301/1000
# Succesfully saved x0300_ _cmap3.csv
# x0301.pdb - 302/1000
# Succesfully saved x0301_ _cmap3.csv
# x0302.pdb - 303/1000
# Succesfully saved x0302_ _cmap3.csv
# x0303.pdb - 304/1000
# Succesfully saved x0303_ _cmap3.csv
# x0304.pdb - 305/1000
# Succesfully saved x0304_ _cmap3.csv
# x0305.pdb - 306/1000
# Succesfully saved x0305_ _cmap3.csv
# x0306.pdb - 307/1000
# Succesfully saved x0306_ _cmap3.csv
# x0307.pdb - 308/1000
# Succesfully saved x0307_ _cmap3.csv
# x0308.pdb - 309/1000
# Succesfully saved x0308_ _cmap3.csv
# x0309.pdb - 310/1000
# Succesfully saved x0309_ _cmap3.csv
# x0310.pdb - 311/1000
# Succesfully saved x0310_ _cmap3.csv
# x0311.pdb - 312/1000
# Succesfully saved x0311_ _cmap3.csv
# x0312.pdb - 313/1000
# Succesfully saved x0312_ _cmap3.csv
# x0313.pdb - 314/1000
# Succesfully saved x0313_ _cmap3.csv
# x0314.pdb - 315/1000
# Succesfully saved x0314_ _cmap3.csv
# x0315.pdb - 316/1000
# Succesfully saved x0315_ _cmap3.csv
# x0316.pdb - 317/1000
# Succesfully saved x0316_ _cmap3.csv
# x0317.pdb - 318/1000
# Succesfully saved x0317_ _cmap3.csv
# x0318.pdb - 319/1000
# Succesfully saved x0318_ _cmap3.csv
# x0319.pdb - 320/1000
# Succesfully saved x0319_ _cmap3.csv
# x0320.pdb - 321/1000
# Succesfully saved x0320_ _cmap3.csv
# x0321.pdb - 322/1000
# Succesfully saved x0321_ _cmap3.csv
# x0322.pdb - 323/1000
# Succesfully saved x0322_ _cmap3.csv
# x0323.pdb - 324/1000
# Succesfully saved x0323_ _cmap3.csv
# x0324.pdb - 325/1000
# Succesfully saved x0324_ _cmap3.csv
# x0325.pdb - 326/1000
# Succesfully saved x0325_ _cmap3.csv
# x0326.pdb - 327/1000
# Succesfully saved x0326_ _cmap3.csv
# x0327.pdb - 328/1000
# Succesfully saved x0327_ _cmap3.csv
# x0328.pdb - 329/1000
# Succesfully saved x0328_ _cmap3.csv
# x0329.pdb - 330/1000
# Succesfully saved x0329_ _cmap3.csv
# x0330.pdb - 331/1000
# Succesfully saved x0330_ _cmap3.csv
# x0331.pdb - 332/1000
# Succesfully saved x0331_ _cmap3.csv
# x0332.pdb - 333/1000
# Succesfully saved x0332_ _cmap3.csv
# x0333.pdb - 334/1000
# Succesfully saved x0333_ _cmap3.csv
# x0334.pdb - 335/1000
# Succesfully saved x0334_ _cmap3.csv
# x0335.pdb - 336/1000
# Succesfully saved x0335_ _cmap3.csv
# x0336.pdb - 337/1000
# Succesfully saved x0336_ _cmap3.csv
# x0337.pdb - 338/1000
# Succesfully saved x0337_ _cmap3.csv
# x0338.pdb - 339/1000
# Succesfully saved x0338_ _cmap3.csv
# x0339.pdb - 340/1000
# Succesfully saved x0339_ _cmap3.csv
# x0340.pdb - 341/1000
# Succesfully saved x0340_ _cmap3.csv
# x0341.pdb - 342/1000
# Succesfully saved x0341_ _cmap3.csv
# x0342.pdb - 343/1000
# Succesfully saved x0342_ _cmap3.csv
# x0343.pdb - 344/1000
# Succesfully saved x0343_ _cmap3.csv
# x0344.pdb - 345/1000
# Succesfully saved x0344_ _cmap3.csv
# x0345.pdb - 346/1000
# Succesfully saved x0345_ _cmap3.csv
# x0346.pdb - 347/1000
# Succesfully saved x0346_ _cmap3.csv
# x0347.pdb - 348/1000
# Succesfully saved x0347_ _cmap3.csv
# x0348.pdb - 349/1000
# Succesfully saved x0348_ _cmap3.csv
# x0349.pdb - 350/1000
# Succesfully saved x0349_ _cmap3.csv
# x0350.pdb - 351/1000
# Succesfully saved x0350_ _cmap3.csv
# x0351.pdb - 352/1000
# Succesfully saved x0351_ _cmap3.csv
# x0352.pdb - 353/1000
# Succesfully saved x0352_ _cmap3.csv
# x0353.pdb - 354/1000
# Succesfully saved x0353_ _cmap3.csv
# x0354.pdb - 355/1000
# Succesfully saved x0354_ _cmap3.csv
# x0355.pdb - 356/1000
# Succesfully saved x0355_ _cmap3.csv
# x0356.pdb - 357/1000
# Succesfully saved x0356_ _cmap3.csv
# x0357.pdb - 358/1000
# Succesfully saved x0357_ _cmap3.csv
# x0358.pdb - 359/1000
# Succesfully saved x0358_ _cmap3.csv
# x0359.pdb - 360/1000
# Succesfully saved x0359_ _cmap3.csv
# x0360.pdb - 361/1000
# Succesfully saved x0360_ _cmap3.csv
# x0361.pdb - 362/1000
# Succesfully saved x0361_ _cmap3.csv
# x0362.pdb - 363/1000
# Succesfully saved x0362_ _cmap3.csv
# x0363.pdb - 364/1000
# Succesfully saved x0363_ _cmap3.csv
# x0364.pdb - 365/1000
# Succesfully saved x0364_ _cmap3.csv
# x0365.pdb - 366/1000
# Succesfully saved x0365_ _cmap3.csv
# x0366.pdb - 367/1000
# Succesfully saved x0366_ _cmap3.csv
# x0367.pdb - 368/1000
# Succesfully saved x0367_ _cmap3.csv
# x0368.pdb - 369/1000
# Succesfully saved x0368_ _cmap3.csv
# x0369.pdb - 370/1000
# Succesfully saved x0369_ _cmap3.csv
# x0370.pdb - 371/1000
# Succesfully saved x0370_ _cmap3.csv
# x0371.pdb - 372/1000
# Succesfully saved x0371_ _cmap3.csv
# x0372.pdb - 373/1000
# Succesfully saved x0372_ _cmap3.csv
# x0373.pdb - 374/1000
# Succesfully saved x0373_ _cmap3.csv
# x0374.pdb - 375/1000
# Succesfully saved x0374_ _cmap3.csv
# x0375.pdb - 376/1000
# Succesfully saved x0375_ _cmap3.csv
# x0376.pdb - 377/1000
# Succesfully saved x0376_ _cmap3.csv
# x0377.pdb - 378/1000
# Succesfully saved x0377_ _cmap3.csv
# x0378.pdb - 379/1000
# Succesfully saved x0378_ _cmap3.csv
# x0379.pdb - 380/1000
# Succesfully saved x0379_ _cmap3.csv
# x0380.pdb - 381/1000
# Succesfully saved x0380_ _cmap3.csv
# x0381.pdb - 382/1000
# Succesfully saved x0381_ _cmap3.csv
# x0382.pdb - 383/1000
# Succesfully saved x0382_ _cmap3.csv
# x0383.pdb - 384/1000
# Succesfully saved x0383_ _cmap3.csv
# x0384.pdb - 385/1000
# Succesfully saved x0384_ _cmap3.csv
# x0385.pdb - 386/1000
# Succesfully saved x0385_ _cmap3.csv
# x0386.pdb - 387/1000
# Succesfully saved x0386_ _cmap3.csv
# x0387.pdb - 388/1000
# Succesfully saved x0387_ _cmap3.csv
# x0388.pdb - 389/1000
# Succesfully saved x0388_ _cmap3.csv
# x0389.pdb - 390/1000
# Succesfully saved x0389_ _cmap3.csv
# x0390.pdb - 391/1000
# Succesfully saved x0390_ _cmap3.csv
# x0391.pdb - 392/1000
# Succesfully saved x0391_ _cmap3.csv
# x0392.pdb - 393/1000
# Succesfully saved x0392_ _cmap3.csv
# x0393.pdb - 394/1000
# Succesfully saved x0393_ _cmap3.csv
# x0394.pdb - 395/1000
# Succesfully saved x0394_ _cmap3.csv
# x0395.pdb - 396/1000
# Succesfully saved x0395_ _cmap3.csv
# x0396.pdb - 397/1000
# Succesfully saved x0396_ _cmap3.csv
# x0397.pdb - 398/1000
# Succesfully saved x0397_ _cmap3.csv
# x0398.pdb - 399/1000
# Succesfully saved x0398_ _cmap3.csv
# x0399.pdb - 400/1000
# Succesfully saved x0399_ _cmap3.csv
# x0400.pdb - 401/1000
# Succesfully saved x0400_ _cmap3.csv
# x0401.pdb - 402/1000
# Succesfully saved x0401_ _cmap3.csv
# x0402.pdb - 403/1000
# Succesfully saved x0402_ _cmap3.csv
# x0403.pdb - 404/1000
# Succesfully saved x0403_ _cmap3.csv
# x0404.pdb - 405/1000
# Succesfully saved x0404_ _cmap3.csv
# x0405.pdb - 406/1000
# Succesfully saved x0405_ _cmap3.csv
# x0406.pdb - 407/1000
# Succesfully saved x0406_ _cmap3.csv
# x0407.pdb - 408/1000
# Succesfully saved x0407_ _cmap3.csv
# x0408.pdb - 409/1000
# Succesfully saved x0408_ _cmap3.csv
# x0409.pdb - 410/1000
# Succesfully saved x0409_ _cmap3.csv
# x0410.pdb - 411/1000
# Succesfully saved x0410_ _cmap3.csv
# x0411.pdb - 412/1000
# Succesfully saved x0411_ _cmap3.csv
# x0412.pdb - 413/1000
# Succesfully saved x0412_ _cmap3.csv
# x0413.pdb - 414/1000
# Succesfully saved x0413_ _cmap3.csv
# x0414.pdb - 415/1000
# Succesfully saved x0414_ _cmap3.csv
# x0415.pdb - 416/1000
# Succesfully saved x0415_ _cmap3.csv
# x0416.pdb - 417/1000
# Succesfully saved x0416_ _cmap3.csv
# x0417.pdb - 418/1000
# Succesfully saved x0417_ _cmap3.csv
# x0418.pdb - 419/1000
# Succesfully saved x0418_ _cmap3.csv
# x0419.pdb - 420/1000
# Succesfully saved x0419_ _cmap3.csv
# x0420.pdb - 421/1000
# Succesfully saved x0420_ _cmap3.csv
# x0421.pdb - 422/1000
# Succesfully saved x0421_ _cmap3.csv
# x0422.pdb - 423/1000
# Succesfully saved x0422_ _cmap3.csv
# x0423.pdb - 424/1000
# Succesfully saved x0423_ _cmap3.csv
# x0424.pdb - 425/1000
# Succesfully saved x0424_ _cmap3.csv
# x0425.pdb - 426/1000
# Succesfully saved x0425_ _cmap3.csv
# x0426.pdb - 427/1000
# Succesfully saved x0426_ _cmap3.csv
# x0427.pdb - 428/1000
# Succesfully saved x0427_ _cmap3.csv
# x0428.pdb - 429/1000
# Succesfully saved x0428_ _cmap3.csv
# x0429.pdb - 430/1000
# Succesfully saved x0429_ _cmap3.csv
# x0430.pdb - 431/1000
# Succesfully saved x0430_ _cmap3.csv
# x0431.pdb - 432/1000
# Succesfully saved x0431_ _cmap3.csv
# x0432.pdb - 433/1000
# Succesfully saved x0432_ _cmap3.csv
# x0433.pdb - 434/1000
# Succesfully saved x0433_ _cmap3.csv
# x0434.pdb - 435/1000
# Succesfully saved x0434_ _cmap3.csv
# x0435.pdb - 436/1000
# Succesfully saved x0435_ _cmap3.csv
# x0436.pdb - 437/1000
# Succesfully saved x0436_ _cmap3.csv
# x0437.pdb - 438/1000
# Succesfully saved x0437_ _cmap3.csv
# x0438.pdb - 439/1000
# Succesfully saved x0438_ _cmap3.csv
# x0439.pdb - 440/1000
# Succesfully saved x0439_ _cmap3.csv
# x0440.pdb - 441/1000
# Succesfully saved x0440_ _cmap3.csv
# x0441.pdb - 442/1000
# Succesfully saved x0441_ _cmap3.csv
# x0442.pdb - 443/1000
# Succesfully saved x0442_ _cmap3.csv
# x0443.pdb - 444/1000
# Succesfully saved x0443_ _cmap3.csv
# x0444.pdb - 445/1000
# Succesfully saved x0444_ _cmap3.csv
# x0445.pdb - 446/1000
# Succesfully saved x0445_ _cmap3.csv
# x0446.pdb - 447/1000
# Succesfully saved x0446_ _cmap3.csv
# x0447.pdb - 448/1000
# Succesfully saved x0447_ _cmap3.csv
# x0448.pdb - 449/1000
# Succesfully saved x0448_ _cmap3.csv
# x0449.pdb - 450/1000
# Succesfully saved x0449_ _cmap3.csv
# x0450.pdb - 451/1000
# Succesfully saved x0450_ _cmap3.csv
# x0451.pdb - 452/1000
# Succesfully saved x0451_ _cmap3.csv
# x0452.pdb - 453/1000
# Succesfully saved x0452_ _cmap3.csv
# x0453.pdb - 454/1000
# Succesfully saved x0453_ _cmap3.csv
# x0454.pdb - 455/1000
# Succesfully saved x0454_ _cmap3.csv
# x0455.pdb - 456/1000
# Succesfully saved x0455_ _cmap3.csv
# x0456.pdb - 457/1000
# Succesfully saved x0456_ _cmap3.csv
# x0457.pdb - 458/1000
# Succesfully saved x0457_ _cmap3.csv
# x0458.pdb - 459/1000
# Succesfully saved x0458_ _cmap3.csv
# x0459.pdb - 460/1000
# Succesfully saved x0459_ _cmap3.csv
# x0460.pdb - 461/1000
# Succesfully saved x0460_ _cmap3.csv
# x0461.pdb - 462/1000
# Succesfully saved x0461_ _cmap3.csv
# x0462.pdb - 463/1000
# Succesfully saved x0462_ _cmap3.csv
# x0463.pdb - 464/1000
# Succesfully saved x0463_ _cmap3.csv
# x0464.pdb - 465/1000
# Succesfully saved x0464_ _cmap3.csv
# x0465.pdb - 466/1000
# Succesfully saved x0465_ _cmap3.csv
# x0466.pdb - 467/1000
# Succesfully saved x0466_ _cmap3.csv
# x0467.pdb - 468/1000
# Succesfully saved x0467_ _cmap3.csv
# x0468.pdb - 469/1000
# Succesfully saved x0468_ _cmap3.csv
# x0469.pdb - 470/1000
# Succesfully saved x0469_ _cmap3.csv
# x0470.pdb - 471/1000
# Succesfully saved x0470_ _cmap3.csv
# x0471.pdb - 472/1000
# Succesfully saved x0471_ _cmap3.csv
# x0472.pdb - 473/1000
# Succesfully saved x0472_ _cmap3.csv
# x0473.pdb - 474/1000
# Succesfully saved x0473_ _cmap3.csv
# x0474.pdb - 475/1000
# Succesfully saved x0474_ _cmap3.csv
# x0475.pdb - 476/1000
# Succesfully saved x0475_ _cmap3.csv
# x0476.pdb - 477/1000
# Succesfully saved x0476_ _cmap3.csv
# x0477.pdb - 478/1000
# Succesfully saved x0477_ _cmap3.csv
# x0478.pdb - 479/1000
# Succesfully saved x0478_ _cmap3.csv
# x0479.pdb - 480/1000
# Succesfully saved x0479_ _cmap3.csv
# x0480.pdb - 481/1000
# Succesfully saved x0480_ _cmap3.csv
# x0481.pdb - 482/1000
# Succesfully saved x0481_ _cmap3.csv
# x0482.pdb - 483/1000
# Succesfully saved x0482_ _cmap3.csv
# x0483.pdb - 484/1000
# Succesfully saved x0483_ _cmap3.csv
# x0484.pdb - 485/1000
# Succesfully saved x0484_ _cmap3.csv
# x0485.pdb - 486/1000
# Succesfully saved x0485_ _cmap3.csv
# x0486.pdb - 487/1000
# Succesfully saved x0486_ _cmap3.csv
# x0487.pdb - 488/1000
# Succesfully saved x0487_ _cmap3.csv
# x0488.pdb - 489/1000
# Succesfully saved x0488_ _cmap3.csv
# x0489.pdb - 490/1000
# Succesfully saved x0489_ _cmap3.csv
# x0490.pdb - 491/1000
# Succesfully saved x0490_ _cmap3.csv
# x0491.pdb - 492/1000
# Succesfully saved x0491_ _cmap3.csv
# x0492.pdb - 493/1000
# Succesfully saved x0492_ _cmap3.csv
# x0493.pdb - 494/1000
# Succesfully saved x0493_ _cmap3.csv
# x0494.pdb - 495/1000
# Succesfully saved x0494_ _cmap3.csv
# x0495.pdb - 496/1000
# Succesfully saved x0495_ _cmap3.csv
# x0496.pdb - 497/1000
# Succesfully saved x0496_ _cmap3.csv
# x0497.pdb - 498/1000
# Succesfully saved x0497_ _cmap3.csv
# x0498.pdb - 499/1000
# Succesfully saved x0498_ _cmap3.csv
# x0499.pdb - 500/1000
# Succesfully saved x0499_ _cmap3.csv
# x0500.pdb - 501/1000
# Succesfully saved x0500_ _cmap3.csv
# x0501.pdb - 502/1000
# Succesfully saved x0501_ _cmap3.csv
# x0502.pdb - 503/1000
# Succesfully saved x0502_ _cmap3.csv
# x0503.pdb - 504/1000
# Succesfully saved x0503_ _cmap3.csv
# x0504.pdb - 505/1000
# Succesfully saved x0504_ _cmap3.csv
# x0505.pdb - 506/1000
# Succesfully saved x0505_ _cmap3.csv
# x0506.pdb - 507/1000
# Succesfully saved x0506_ _cmap3.csv
# x0507.pdb - 508/1000
# Succesfully saved x0507_ _cmap3.csv
# x0508.pdb - 509/1000
# Succesfully saved x0508_ _cmap3.csv
# x0509.pdb - 510/1000
# Succesfully saved x0509_ _cmap3.csv
# x0510.pdb - 511/1000
# Succesfully saved x0510_ _cmap3.csv
# x0511.pdb - 512/1000
# Succesfully saved x0511_ _cmap3.csv
# x0512.pdb - 513/1000
# Succesfully saved x0512_ _cmap3.csv
# x0513.pdb - 514/1000
# Succesfully saved x0513_ _cmap3.csv
# x0514.pdb - 515/1000
# Succesfully saved x0514_ _cmap3.csv
# x0515.pdb - 516/1000
# Succesfully saved x0515_ _cmap3.csv
# x0516.pdb - 517/1000
# Succesfully saved x0516_ _cmap3.csv
# x0517.pdb - 518/1000
# Succesfully saved x0517_ _cmap3.csv
# x0518.pdb - 519/1000
# Succesfully saved x0518_ _cmap3.csv
# x0519.pdb - 520/1000
# Succesfully saved x0519_ _cmap3.csv
# x0520.pdb - 521/1000
# Succesfully saved x0520_ _cmap3.csv
# x0521.pdb - 522/1000
# Succesfully saved x0521_ _cmap3.csv
# x0522.pdb - 523/1000
# Succesfully saved x0522_ _cmap3.csv
# x0523.pdb - 524/1000
# Succesfully saved x0523_ _cmap3.csv
# x0524.pdb - 525/1000
# Succesfully saved x0524_ _cmap3.csv
# x0525.pdb - 526/1000
# Succesfully saved x0525_ _cmap3.csv
# x0526.pdb - 527/1000
# Succesfully saved x0526_ _cmap3.csv
# x0527.pdb - 528/1000
# Succesfully saved x0527_ _cmap3.csv
# x0528.pdb - 529/1000
# Succesfully saved x0528_ _cmap3.csv
# x0529.pdb - 530/1000
# Succesfully saved x0529_ _cmap3.csv
# x0530.pdb - 531/1000
# Succesfully saved x0530_ _cmap3.csv
# x0531.pdb - 532/1000
# Succesfully saved x0531_ _cmap3.csv
# x0532.pdb - 533/1000
# Succesfully saved x0532_ _cmap3.csv
# x0533.pdb - 534/1000
# Succesfully saved x0533_ _cmap3.csv
# x0534.pdb - 535/1000
# Succesfully saved x0534_ _cmap3.csv
# x0535.pdb - 536/1000
# Succesfully saved x0535_ _cmap3.csv
# x0536.pdb - 537/1000
# Succesfully saved x0536_ _cmap3.csv
# x0537.pdb - 538/1000
# Succesfully saved x0537_ _cmap3.csv
# x0538.pdb - 539/1000
# Succesfully saved x0538_ _cmap3.csv
# x0539.pdb - 540/1000
# Succesfully saved x0539_ _cmap3.csv
# x0540.pdb - 541/1000
# Succesfully saved x0540_ _cmap3.csv
# x0541.pdb - 542/1000
# Succesfully saved x0541_ _cmap3.csv
# x0542.pdb - 543/1000
# Succesfully saved x0542_ _cmap3.csv
# x0543.pdb - 544/1000
# Succesfully saved x0543_ _cmap3.csv
# x0544.pdb - 545/1000
# Succesfully saved x0544_ _cmap3.csv
# x0545.pdb - 546/1000
# Succesfully saved x0545_ _cmap3.csv
# x0546.pdb - 547/1000
# Succesfully saved x0546_ _cmap3.csv
# x0547.pdb - 548/1000
# Succesfully saved x0547_ _cmap3.csv
# x0548.pdb - 549/1000
# Succesfully saved x0548_ _cmap3.csv
# x0549.pdb - 550/1000
# Succesfully saved x0549_ _cmap3.csv
# x0550.pdb - 551/1000
# Succesfully saved x0550_ _cmap3.csv
# x0551.pdb - 552/1000
# Succesfully saved x0551_ _cmap3.csv
# x0552.pdb - 553/1000
# Succesfully saved x0552_ _cmap3.csv
# x0553.pdb - 554/1000
# Succesfully saved x0553_ _cmap3.csv
# x0554.pdb - 555/1000
# Succesfully saved x0554_ _cmap3.csv
# x0555.pdb - 556/1000
# Succesfully saved x0555_ _cmap3.csv
# x0556.pdb - 557/1000
# Succesfully saved x0556_ _cmap3.csv
# x0557.pdb - 558/1000
# Succesfully saved x0557_ _cmap3.csv
# x0558.pdb - 559/1000
# Succesfully saved x0558_ _cmap3.csv
# x0559.pdb - 560/1000
# Succesfully saved x0559_ _cmap3.csv
# x0560.pdb - 561/1000
# Succesfully saved x0560_ _cmap3.csv
# x0561.pdb - 562/1000
# Succesfully saved x0561_ _cmap3.csv
# x0562.pdb - 563/1000
# Succesfully saved x0562_ _cmap3.csv
# x0563.pdb - 564/1000
# Succesfully saved x0563_ _cmap3.csv
# x0564.pdb - 565/1000
# Succesfully saved x0564_ _cmap3.csv
# x0565.pdb - 566/1000
# Succesfully saved x0565_ _cmap3.csv
# x0566.pdb - 567/1000
# Succesfully saved x0566_ _cmap3.csv
# x0567.pdb - 568/1000
# Succesfully saved x0567_ _cmap3.csv
# x0568.pdb - 569/1000
# Succesfully saved x0568_ _cmap3.csv
# x0569.pdb - 570/1000
# Succesfully saved x0569_ _cmap3.csv
# x0570.pdb - 571/1000
# Succesfully saved x0570_ _cmap3.csv
# x0571.pdb - 572/1000
# Succesfully saved x0571_ _cmap3.csv
# x0572.pdb - 573/1000
# Succesfully saved x0572_ _cmap3.csv
# x0573.pdb - 574/1000
# Succesfully saved x0573_ _cmap3.csv
# x0574.pdb - 575/1000
# Succesfully saved x0574_ _cmap3.csv
# x0575.pdb - 576/1000
# Succesfully saved x0575_ _cmap3.csv
# x0576.pdb - 577/1000
# Succesfully saved x0576_ _cmap3.csv
# x0577.pdb - 578/1000
# Succesfully saved x0577_ _cmap3.csv
# x0578.pdb - 579/1000
# Succesfully saved x0578_ _cmap3.csv
# x0579.pdb - 580/1000
# Succesfully saved x0579_ _cmap3.csv
# x0580.pdb - 581/1000
# Succesfully saved x0580_ _cmap3.csv
# x0581.pdb - 582/1000
# Succesfully saved x0581_ _cmap3.csv
# x0582.pdb - 583/1000
# Succesfully saved x0582_ _cmap3.csv
# x0583.pdb - 584/1000
# Succesfully saved x0583_ _cmap3.csv
# x0584.pdb - 585/1000
# Succesfully saved x0584_ _cmap3.csv
# x0585.pdb - 586/1000
# Succesfully saved x0585_ _cmap3.csv
# x0586.pdb - 587/1000
# Succesfully saved x0586_ _cmap3.csv
# x0587.pdb - 588/1000
# Succesfully saved x0587_ _cmap3.csv
# x0588.pdb - 589/1000
# Succesfully saved x0588_ _cmap3.csv
# x0589.pdb - 590/1000
# Succesfully saved x0589_ _cmap3.csv
# x0590.pdb - 591/1000
# Succesfully saved x0590_ _cmap3.csv
# x0591.pdb - 592/1000
# Succesfully saved x0591_ _cmap3.csv
# x0592.pdb - 593/1000
# Succesfully saved x0592_ _cmap3.csv
# x0593.pdb - 594/1000
# Succesfully saved x0593_ _cmap3.csv
# x0594.pdb - 595/1000
# Succesfully saved x0594_ _cmap3.csv
# x0595.pdb - 596/1000
# Succesfully saved x0595_ _cmap3.csv
# x0596.pdb - 597/1000
# Succesfully saved x0596_ _cmap3.csv
# x0597.pdb - 598/1000
# Succesfully saved x0597_ _cmap3.csv
# x0598.pdb - 599/1000
# Succesfully saved x0598_ _cmap3.csv
# x0599.pdb - 600/1000
# Succesfully saved x0599_ _cmap3.csv
# x0600.pdb - 601/1000
# Succesfully saved x0600_ _cmap3.csv
# x0601.pdb - 602/1000
# Succesfully saved x0601_ _cmap3.csv
# x0602.pdb - 603/1000
# Succesfully saved x0602_ _cmap3.csv
# x0603.pdb - 604/1000
# Succesfully saved x0603_ _cmap3.csv
# x0604.pdb - 605/1000
# Succesfully saved x0604_ _cmap3.csv
# x0605.pdb - 606/1000
# Succesfully saved x0605_ _cmap3.csv
# x0606.pdb - 607/1000
# Succesfully saved x0606_ _cmap3.csv
# x0607.pdb - 608/1000
# Succesfully saved x0607_ _cmap3.csv
# x0608.pdb - 609/1000
# Succesfully saved x0608_ _cmap3.csv
# x0609.pdb - 610/1000
# Succesfully saved x0609_ _cmap3.csv
# x0610.pdb - 611/1000
# Succesfully saved x0610_ _cmap3.csv
# x0611.pdb - 612/1000
# Succesfully saved x0611_ _cmap3.csv
# x0612.pdb - 613/1000
# Succesfully saved x0612_ _cmap3.csv
# x0613.pdb - 614/1000
# Succesfully saved x0613_ _cmap3.csv
# x0614.pdb - 615/1000
# Succesfully saved x0614_ _cmap3.csv
# x0615.pdb - 616/1000
# Succesfully saved x0615_ _cmap3.csv
# x0616.pdb - 617/1000
# Succesfully saved x0616_ _cmap3.csv
# x0617.pdb - 618/1000
# Succesfully saved x0617_ _cmap3.csv
# x0618.pdb - 619/1000
# Succesfully saved x0618_ _cmap3.csv
# x0619.pdb - 620/1000
# Succesfully saved x0619_ _cmap3.csv
# x0620.pdb - 621/1000
# Succesfully saved x0620_ _cmap3.csv
# x0621.pdb - 622/1000
# Succesfully saved x0621_ _cmap3.csv
# x0622.pdb - 623/1000
# Succesfully saved x0622_ _cmap3.csv
# x0623.pdb - 624/1000
# Succesfully saved x0623_ _cmap3.csv
# x0624.pdb - 625/1000
# Succesfully saved x0624_ _cmap3.csv
# x0625.pdb - 626/1000
# Succesfully saved x0625_ _cmap3.csv
# x0626.pdb - 627/1000
# Succesfully saved x0626_ _cmap3.csv
# x0627.pdb - 628/1000
# Succesfully saved x0627_ _cmap3.csv
# x0628.pdb - 629/1000
# Succesfully saved x0628_ _cmap3.csv
# x0629.pdb - 630/1000
# Succesfully saved x0629_ _cmap3.csv
# x0630.pdb - 631/1000
# Succesfully saved x0630_ _cmap3.csv
# x0631.pdb - 632/1000
# Succesfully saved x0631_ _cmap3.csv
# x0632.pdb - 633/1000
# Succesfully saved x0632_ _cmap3.csv
# x0633.pdb - 634/1000
# Succesfully saved x0633_ _cmap3.csv
# x0634.pdb - 635/1000
# Succesfully saved x0634_ _cmap3.csv
# x0635.pdb - 636/1000
# Succesfully saved x0635_ _cmap3.csv
# x0636.pdb - 637/1000
# Succesfully saved x0636_ _cmap3.csv
# x0637.pdb - 638/1000
# Succesfully saved x0637_ _cmap3.csv
# x0638.pdb - 639/1000
# Succesfully saved x0638_ _cmap3.csv
# x0639.pdb - 640/1000
# Succesfully saved x0639_ _cmap3.csv
# x0640.pdb - 641/1000
# Succesfully saved x0640_ _cmap3.csv
# x0641.pdb - 642/1000
# Succesfully saved x0641_ _cmap3.csv
# x0642.pdb - 643/1000
# Succesfully saved x0642_ _cmap3.csv
# x0643.pdb - 644/1000
# Succesfully saved x0643_ _cmap3.csv
# x0644.pdb - 645/1000
# Succesfully saved x0644_ _cmap3.csv
# x0645.pdb - 646/1000
# Succesfully saved x0645_ _cmap3.csv
# x0646.pdb - 647/1000
# Succesfully saved x0646_ _cmap3.csv
# x0647.pdb - 648/1000
# Succesfully saved x0647_ _cmap3.csv
# x0648.pdb - 649/1000
# Succesfully saved x0648_ _cmap3.csv
# x0649.pdb - 650/1000
# Succesfully saved x0649_ _cmap3.csv
# x0650.pdb - 651/1000
# Succesfully saved x0650_ _cmap3.csv
# x0651.pdb - 652/1000
# Succesfully saved x0651_ _cmap3.csv
# x0652.pdb - 653/1000
# Succesfully saved x0652_ _cmap3.csv
# x0653.pdb - 654/1000
# Succesfully saved x0653_ _cmap3.csv
# x0654.pdb - 655/1000
# Succesfully saved x0654_ _cmap3.csv
# x0655.pdb - 656/1000
# Succesfully saved x0655_ _cmap3.csv
# x0656.pdb - 657/1000
# Succesfully saved x0656_ _cmap3.csv
# x0657.pdb - 658/1000
# Succesfully saved x0657_ _cmap3.csv
# x0658.pdb - 659/1000
# Succesfully saved x0658_ _cmap3.csv
# x0659.pdb - 660/1000
# Succesfully saved x0659_ _cmap3.csv
# x0660.pdb - 661/1000
# Succesfully saved x0660_ _cmap3.csv
# x0661.pdb - 662/1000
# Succesfully saved x0661_ _cmap3.csv
# x0662.pdb - 663/1000
# Succesfully saved x0662_ _cmap3.csv
# x0663.pdb - 664/1000
# Succesfully saved x0663_ _cmap3.csv
# x0664.pdb - 665/1000
# Succesfully saved x0664_ _cmap3.csv
# x0665.pdb - 666/1000
# Succesfully saved x0665_ _cmap3.csv
# x0666.pdb - 667/1000
# Succesfully saved x0666_ _cmap3.csv
# x0667.pdb - 668/1000
# Succesfully saved x0667_ _cmap3.csv
# x0668.pdb - 669/1000
# Succesfully saved x0668_ _cmap3.csv
# x0669.pdb - 670/1000
# Succesfully saved x0669_ _cmap3.csv
# x0670.pdb - 671/1000
# Succesfully saved x0670_ _cmap3.csv
# x0671.pdb - 672/1000
# Succesfully saved x0671_ _cmap3.csv
# x0672.pdb - 673/1000
# Succesfully saved x0672_ _cmap3.csv
# x0673.pdb - 674/1000
# Succesfully saved x0673_ _cmap3.csv
# x0674.pdb - 675/1000
# Succesfully saved x0674_ _cmap3.csv
# x0675.pdb - 676/1000
# Succesfully saved x0675_ _cmap3.csv
# x0676.pdb - 677/1000
# Succesfully saved x0676_ _cmap3.csv
# x0677.pdb - 678/1000
# Succesfully saved x0677_ _cmap3.csv
# x0678.pdb - 679/1000
# Succesfully saved x0678_ _cmap3.csv
# x0679.pdb - 680/1000
# Succesfully saved x0679_ _cmap3.csv
# x0680.pdb - 681/1000
# Succesfully saved x0680_ _cmap3.csv
# x0681.pdb - 682/1000
# Succesfully saved x0681_ _cmap3.csv
# x0682.pdb - 683/1000
# Succesfully saved x0682_ _cmap3.csv
# x0683.pdb - 684/1000
# Succesfully saved x0683_ _cmap3.csv
# x0684.pdb - 685/1000
# Succesfully saved x0684_ _cmap3.csv
# x0685.pdb - 686/1000
# Succesfully saved x0685_ _cmap3.csv
# x0686.pdb - 687/1000
# Succesfully saved x0686_ _cmap3.csv
# x0687.pdb - 688/1000
# Succesfully saved x0687_ _cmap3.csv
# x0688.pdb - 689/1000
# Succesfully saved x0688_ _cmap3.csv
# x0689.pdb - 690/1000
# Succesfully saved x0689_ _cmap3.csv
# x0690.pdb - 691/1000
# Succesfully saved x0690_ _cmap3.csv
# x0691.pdb - 692/1000
# Succesfully saved x0691_ _cmap3.csv
# x0692.pdb - 693/1000
# Succesfully saved x0692_ _cmap3.csv
# x0693.pdb - 694/1000
# Succesfully saved x0693_ _cmap3.csv
# x0694.pdb - 695/1000
# Succesfully saved x0694_ _cmap3.csv
# x0695.pdb - 696/1000
# Succesfully saved x0695_ _cmap3.csv
# x0696.pdb - 697/1000
# Succesfully saved x0696_ _cmap3.csv
# x0697.pdb - 698/1000
# Succesfully saved x0697_ _cmap3.csv
# x0698.pdb - 699/1000
# Succesfully saved x0698_ _cmap3.csv
# x0699.pdb - 700/1000
# Succesfully saved x0699_ _cmap3.csv
# x0700.pdb - 701/1000
# Succesfully saved x0700_ _cmap3.csv
# x0701.pdb - 702/1000
# Succesfully saved x0701_ _cmap3.csv
# x0702.pdb - 703/1000
# Succesfully saved x0702_ _cmap3.csv
# x0703.pdb - 704/1000
# Succesfully saved x0703_ _cmap3.csv
# x0704.pdb - 705/1000
# Succesfully saved x0704_ _cmap3.csv
# x0705.pdb - 706/1000
# Succesfully saved x0705_ _cmap3.csv
# x0706.pdb - 707/1000
# Succesfully saved x0706_ _cmap3.csv
# x0707.pdb - 708/1000
# Succesfully saved x0707_ _cmap3.csv
# x0708.pdb - 709/1000
# Succesfully saved x0708_ _cmap3.csv
# x0709.pdb - 710/1000
# Succesfully saved x0709_ _cmap3.csv
# x0710.pdb - 711/1000
# Succesfully saved x0710_ _cmap3.csv
# x0711.pdb - 712/1000
# Succesfully saved x0711_ _cmap3.csv
# x0712.pdb - 713/1000
# Succesfully saved x0712_ _cmap3.csv
# x0713.pdb - 714/1000
# Succesfully saved x0713_ _cmap3.csv
# x0714.pdb - 715/1000
# Succesfully saved x0714_ _cmap3.csv
# x0715.pdb - 716/1000
# Succesfully saved x0715_ _cmap3.csv
# x0716.pdb - 717/1000
# Succesfully saved x0716_ _cmap3.csv
# x0717.pdb - 718/1000
# Succesfully saved x0717_ _cmap3.csv
# x0718.pdb - 719/1000
# Succesfully saved x0718_ _cmap3.csv
# x0719.pdb - 720/1000
# Succesfully saved x0719_ _cmap3.csv
# x0720.pdb - 721/1000
# Succesfully saved x0720_ _cmap3.csv
# x0721.pdb - 722/1000
# Succesfully saved x0721_ _cmap3.csv
# x0722.pdb - 723/1000
# Succesfully saved x0722_ _cmap3.csv
# x0723.pdb - 724/1000
# Succesfully saved x0723_ _cmap3.csv
# x0724.pdb - 725/1000
# Succesfully saved x0724_ _cmap3.csv
# x0725.pdb - 726/1000
# Succesfully saved x0725_ _cmap3.csv
# x0726.pdb - 727/1000
# Succesfully saved x0726_ _cmap3.csv
# x0727.pdb - 728/1000
# Succesfully saved x0727_ _cmap3.csv
# x0728.pdb - 729/1000
# Succesfully saved x0728_ _cmap3.csv
# x0729.pdb - 730/1000
# Succesfully saved x0729_ _cmap3.csv
# x0730.pdb - 731/1000
# Succesfully saved x0730_ _cmap3.csv
# x0731.pdb - 732/1000
# Succesfully saved x0731_ _cmap3.csv
# x0732.pdb - 733/1000
# Succesfully saved x0732_ _cmap3.csv
# x0733.pdb - 734/1000
# Succesfully saved x0733_ _cmap3.csv
# x0734.pdb - 735/1000
# Succesfully saved x0734_ _cmap3.csv
# x0735.pdb - 736/1000
# Succesfully saved x0735_ _cmap3.csv
# x0736.pdb - 737/1000
# Succesfully saved x0736_ _cmap3.csv
# x0737.pdb - 738/1000
# Succesfully saved x0737_ _cmap3.csv
# x0738.pdb - 739/1000
# Succesfully saved x0738_ _cmap3.csv
# x0739.pdb - 740/1000
# Succesfully saved x0739_ _cmap3.csv
# x0740.pdb - 741/1000
# Succesfully saved x0740_ _cmap3.csv
# x0741.pdb - 742/1000
# Succesfully saved x0741_ _cmap3.csv
# x0742.pdb - 743/1000
# Succesfully saved x0742_ _cmap3.csv
# x0743.pdb - 744/1000
# Succesfully saved x0743_ _cmap3.csv
# x0744.pdb - 745/1000
# Succesfully saved x0744_ _cmap3.csv
# x0745.pdb - 746/1000
# Succesfully saved x0745_ _cmap3.csv
# x0746.pdb - 747/1000
# Succesfully saved x0746_ _cmap3.csv
# x0747.pdb - 748/1000
# Succesfully saved x0747_ _cmap3.csv
# x0748.pdb - 749/1000
# Succesfully saved x0748_ _cmap3.csv
# x0749.pdb - 750/1000
# Succesfully saved x0749_ _cmap3.csv
# x0750.pdb - 751/1000
# Succesfully saved x0750_ _cmap3.csv
# x0751.pdb - 752/1000
# Succesfully saved x0751_ _cmap3.csv
# x0752.pdb - 753/1000
# Succesfully saved x0752_ _cmap3.csv
# x0753.pdb - 754/1000
# Succesfully saved x0753_ _cmap3.csv
# x0754.pdb - 755/1000
# Succesfully saved x0754_ _cmap3.csv
# x0755.pdb - 756/1000
# Succesfully saved x0755_ _cmap3.csv
# x0756.pdb - 757/1000
# Succesfully saved x0756_ _cmap3.csv
# x0757.pdb - 758/1000
# Succesfully saved x0757_ _cmap3.csv
# x0758.pdb - 759/1000
# Succesfully saved x0758_ _cmap3.csv
# x0759.pdb - 760/1000
# Succesfully saved x0759_ _cmap3.csv
# x0760.pdb - 761/1000
# Succesfully saved x0760_ _cmap3.csv
# x0761.pdb - 762/1000
# Succesfully saved x0761_ _cmap3.csv
# x0762.pdb - 763/1000
# Succesfully saved x0762_ _cmap3.csv
# x0763.pdb - 764/1000
# Succesfully saved x0763_ _cmap3.csv
# x0764.pdb - 765/1000
# Succesfully saved x0764_ _cmap3.csv
# x0765.pdb - 766/1000
# Succesfully saved x0765_ _cmap3.csv
# x0766.pdb - 767/1000
# Succesfully saved x0766_ _cmap3.csv
# x0767.pdb - 768/1000
# Succesfully saved x0767_ _cmap3.csv
# x0768.pdb - 769/1000
# Succesfully saved x0768_ _cmap3.csv
# x0769.pdb - 770/1000
# Succesfully saved x0769_ _cmap3.csv
# x0770.pdb - 771/1000
# Succesfully saved x0770_ _cmap3.csv
# x0771.pdb - 772/1000
# Succesfully saved x0771_ _cmap3.csv
# x0772.pdb - 773/1000
# Succesfully saved x0772_ _cmap3.csv
# x0773.pdb - 774/1000
# Succesfully saved x0773_ _cmap3.csv
# x0774.pdb - 775/1000
# Succesfully saved x0774_ _cmap3.csv
# x0775.pdb - 776/1000
# Succesfully saved x0775_ _cmap3.csv
# x0776.pdb - 777/1000
# Succesfully saved x0776_ _cmap3.csv
# x0777.pdb - 778/1000
# Succesfully saved x0777_ _cmap3.csv
# x0778.pdb - 779/1000
# Succesfully saved x0778_ _cmap3.csv
# x0779.pdb - 780/1000
# Succesfully saved x0779_ _cmap3.csv
# x0780.pdb - 781/1000
# Succesfully saved x0780_ _cmap3.csv
# x0781.pdb - 782/1000
# Succesfully saved x0781_ _cmap3.csv
# x0782.pdb - 783/1000
# Succesfully saved x0782_ _cmap3.csv
# x0783.pdb - 784/1000
# Succesfully saved x0783_ _cmap3.csv
# x0784.pdb - 785/1000
# Succesfully saved x0784_ _cmap3.csv
# x0785.pdb - 786/1000
# Succesfully saved x0785_ _cmap3.csv
# x0786.pdb - 787/1000
# Succesfully saved x0786_ _cmap3.csv
# x0787.pdb - 788/1000
# Succesfully saved x0787_ _cmap3.csv
# x0788.pdb - 789/1000
# Succesfully saved x0788_ _cmap3.csv
# x0789.pdb - 790/1000
# Succesfully saved x0789_ _cmap3.csv
# x0790.pdb - 791/1000
# Succesfully saved x0790_ _cmap3.csv
# x0791.pdb - 792/1000
# Succesfully saved x0791_ _cmap3.csv
# x0792.pdb - 793/1000
# Succesfully saved x0792_ _cmap3.csv
# x0793.pdb - 794/1000
# Succesfully saved x0793_ _cmap3.csv
# x0794.pdb - 795/1000
# Succesfully saved x0794_ _cmap3.csv
# x0795.pdb - 796/1000
# Succesfully saved x0795_ _cmap3.csv
# x0796.pdb - 797/1000
# Succesfully saved x0796_ _cmap3.csv
# x0797.pdb - 798/1000
# Succesfully saved x0797_ _cmap3.csv
# x0798.pdb - 799/1000
# Succesfully saved x0798_ _cmap3.csv
# x0799.pdb - 800/1000
# Succesfully saved x0799_ _cmap3.csv
# x0800.pdb - 801/1000
# Succesfully saved x0800_ _cmap3.csv
# x0801.pdb - 802/1000
# Succesfully saved x0801_ _cmap3.csv
# x0802.pdb - 803/1000
# Succesfully saved x0802_ _cmap3.csv
# x0803.pdb - 804/1000
# Succesfully saved x0803_ _cmap3.csv
# x0804.pdb - 805/1000
# Succesfully saved x0804_ _cmap3.csv
# x0805.pdb - 806/1000
# Succesfully saved x0805_ _cmap3.csv
# x0806.pdb - 807/1000
# Succesfully saved x0806_ _cmap3.csv
# x0807.pdb - 808/1000
# Succesfully saved x0807_ _cmap3.csv
# x0808.pdb - 809/1000
# Succesfully saved x0808_ _cmap3.csv
# x0809.pdb - 810/1000
# Succesfully saved x0809_ _cmap3.csv
# x0810.pdb - 811/1000
# Succesfully saved x0810_ _cmap3.csv
# x0811.pdb - 812/1000
# Succesfully saved x0811_ _cmap3.csv
# x0812.pdb - 813/1000
# Succesfully saved x0812_ _cmap3.csv
# x0813.pdb - 814/1000
# Succesfully saved x0813_ _cmap3.csv
# x0814.pdb - 815/1000
# Succesfully saved x0814_ _cmap3.csv
# x0815.pdb - 816/1000
# Succesfully saved x0815_ _cmap3.csv
# x0816.pdb - 817/1000
# Succesfully saved x0816_ _cmap3.csv
# x0817.pdb - 818/1000
# Succesfully saved x0817_ _cmap3.csv
# x0818.pdb - 819/1000
# Succesfully saved x0818_ _cmap3.csv
# x0819.pdb - 820/1000
# Succesfully saved x0819_ _cmap3.csv
# x0820.pdb - 821/1000
# Succesfully saved x0820_ _cmap3.csv
# x0821.pdb - 822/1000
# Succesfully saved x0821_ _cmap3.csv
# x0822.pdb - 823/1000
# Succesfully saved x0822_ _cmap3.csv
# x0823.pdb - 824/1000
# Succesfully saved x0823_ _cmap3.csv
# x0824.pdb - 825/1000
# Succesfully saved x0824_ _cmap3.csv
# x0825.pdb - 826/1000
# Succesfully saved x0825_ _cmap3.csv
# x0826.pdb - 827/1000
# Succesfully saved x0826_ _cmap3.csv
# x0827.pdb - 828/1000
# Succesfully saved x0827_ _cmap3.csv
# x0828.pdb - 829/1000
# Succesfully saved x0828_ _cmap3.csv
# x0829.pdb - 830/1000
# Succesfully saved x0829_ _cmap3.csv
# x0830.pdb - 831/1000
# Succesfully saved x0830_ _cmap3.csv
# x0831.pdb - 832/1000
# Succesfully saved x0831_ _cmap3.csv
# x0832.pdb - 833/1000
# Succesfully saved x0832_ _cmap3.csv
# x0833.pdb - 834/1000
# Succesfully saved x0833_ _cmap3.csv
# x0834.pdb - 835/1000
# Succesfully saved x0834_ _cmap3.csv
# x0835.pdb - 836/1000
# Succesfully saved x0835_ _cmap3.csv
# x0836.pdb - 837/1000
# Succesfully saved x0836_ _cmap3.csv
# x0837.pdb - 838/1000
# Succesfully saved x0837_ _cmap3.csv
# x0838.pdb - 839/1000
# Succesfully saved x0838_ _cmap3.csv
# x0839.pdb - 840/1000
# Succesfully saved x0839_ _cmap3.csv
# x0840.pdb - 841/1000
# Succesfully saved x0840_ _cmap3.csv
# x0841.pdb - 842/1000
# Succesfully saved x0841_ _cmap3.csv
# x0842.pdb - 843/1000
# Succesfully saved x0842_ _cmap3.csv
# x0843.pdb - 844/1000
# Succesfully saved x0843_ _cmap3.csv
# x0844.pdb - 845/1000
# Succesfully saved x0844_ _cmap3.csv
# x0845.pdb - 846/1000
# Succesfully saved x0845_ _cmap3.csv
# x0846.pdb - 847/1000
# Succesfully saved x0846_ _cmap3.csv
# x0847.pdb - 848/1000
# Succesfully saved x0847_ _cmap3.csv
# x0848.pdb - 849/1000
# Succesfully saved x0848_ _cmap3.csv
# x0849.pdb - 850/1000
# Succesfully saved x0849_ _cmap3.csv
# x0850.pdb - 851/1000
# Succesfully saved x0850_ _cmap3.csv
# x0851.pdb - 852/1000
# Succesfully saved x0851_ _cmap3.csv
# x0852.pdb - 853/1000
# Succesfully saved x0852_ _cmap3.csv
# x0853.pdb - 854/1000
# Succesfully saved x0853_ _cmap3.csv
# x0854.pdb - 855/1000
# Succesfully saved x0854_ _cmap3.csv
# x0855.pdb - 856/1000
# Succesfully saved x0855_ _cmap3.csv
# x0856.pdb - 857/1000
# Succesfully saved x0856_ _cmap3.csv
# x0857.pdb - 858/1000
# Succesfully saved x0857_ _cmap3.csv
# x0858.pdb - 859/1000
# Succesfully saved x0858_ _cmap3.csv
# x0859.pdb - 860/1000
# Succesfully saved x0859_ _cmap3.csv
# x0860.pdb - 861/1000
# Succesfully saved x0860_ _cmap3.csv
# x0861.pdb - 862/1000
# Succesfully saved x0861_ _cmap3.csv
# x0862.pdb - 863/1000
# Succesfully saved x0862_ _cmap3.csv
# x0863.pdb - 864/1000
# Succesfully saved x0863_ _cmap3.csv
# x0864.pdb - 865/1000
# Succesfully saved x0864_ _cmap3.csv
# x0865.pdb - 866/1000
# Succesfully saved x0865_ _cmap3.csv
# x0866.pdb - 867/1000
# Succesfully saved x0866_ _cmap3.csv
# x0867.pdb - 868/1000
# Succesfully saved x0867_ _cmap3.csv
# x0868.pdb - 869/1000
# Succesfully saved x0868_ _cmap3.csv
# x0869.pdb - 870/1000
# Succesfully saved x0869_ _cmap3.csv
# x0870.pdb - 871/1000
# Succesfully saved x0870_ _cmap3.csv
# x0871.pdb - 872/1000
# Succesfully saved x0871_ _cmap3.csv
# x0872.pdb - 873/1000
# Succesfully saved x0872_ _cmap3.csv
# x0873.pdb - 874/1000
# Succesfully saved x0873_ _cmap3.csv
# x0874.pdb - 875/1000
# Succesfully saved x0874_ _cmap3.csv
# x0875.pdb - 876/1000
# Succesfully saved x0875_ _cmap3.csv
# x0876.pdb - 877/1000
# Succesfully saved x0876_ _cmap3.csv
# x0877.pdb - 878/1000
# Succesfully saved x0877_ _cmap3.csv
# x0878.pdb - 879/1000
# Succesfully saved x0878_ _cmap3.csv
# x0879.pdb - 880/1000
# Succesfully saved x0879_ _cmap3.csv
# x0880.pdb - 881/1000
# Succesfully saved x0880_ _cmap3.csv
# x0881.pdb - 882/1000
# Succesfully saved x0881_ _cmap3.csv
# x0882.pdb - 883/1000
# Succesfully saved x0882_ _cmap3.csv
# x0883.pdb - 884/1000
# Succesfully saved x0883_ _cmap3.csv
# x0884.pdb - 885/1000
# Succesfully saved x0884_ _cmap3.csv
# x0885.pdb - 886/1000
# Succesfully saved x0885_ _cmap3.csv
# x0886.pdb - 887/1000
# Succesfully saved x0886_ _cmap3.csv
# x0887.pdb - 888/1000
# Succesfully saved x0887_ _cmap3.csv
# x0888.pdb - 889/1000
# Succesfully saved x0888_ _cmap3.csv
# x0889.pdb - 890/1000
# Succesfully saved x0889_ _cmap3.csv
# x0890.pdb - 891/1000
# Succesfully saved x0890_ _cmap3.csv
# x0891.pdb - 892/1000
# Succesfully saved x0891_ _cmap3.csv
# x0892.pdb - 893/1000
# Succesfully saved x0892_ _cmap3.csv
# x0893.pdb - 894/1000
# Succesfully saved x0893_ _cmap3.csv
# x0894.pdb - 895/1000
# Succesfully saved x0894_ _cmap3.csv
# x0895.pdb - 896/1000
# Succesfully saved x0895_ _cmap3.csv
# x0896.pdb - 897/1000
# Succesfully saved x0896_ _cmap3.csv
# x0897.pdb - 898/1000
# Succesfully saved x0897_ _cmap3.csv
# x0898.pdb - 899/1000
# Succesfully saved x0898_ _cmap3.csv
# x0899.pdb - 900/1000
# Succesfully saved x0899_ _cmap3.csv
# x0900.pdb - 901/1000
# Succesfully saved x0900_ _cmap3.csv
# x0901.pdb - 902/1000
# Succesfully saved x0901_ _cmap3.csv
# x0902.pdb - 903/1000
# Succesfully saved x0902_ _cmap3.csv
# x0903.pdb - 904/1000
# Succesfully saved x0903_ _cmap3.csv
# x0904.pdb - 905/1000
# Succesfully saved x0904_ _cmap3.csv
# x0905.pdb - 906/1000
# Succesfully saved x0905_ _cmap3.csv
# x0906.pdb - 907/1000
# Succesfully saved x0906_ _cmap3.csv
# x0907.pdb - 908/1000
# Succesfully saved x0907_ _cmap3.csv
# x0908.pdb - 909/1000
# Succesfully saved x0908_ _cmap3.csv
# x0909.pdb - 910/1000
# Succesfully saved x0909_ _cmap3.csv
# x0910.pdb - 911/1000
# Succesfully saved x0910_ _cmap3.csv
# x0911.pdb - 912/1000
# Succesfully saved x0911_ _cmap3.csv
# x0912.pdb - 913/1000
# Succesfully saved x0912_ _cmap3.csv
# x0913.pdb - 914/1000
# Succesfully saved x0913_ _cmap3.csv
# x0914.pdb - 915/1000
# Succesfully saved x0914_ _cmap3.csv
# x0915.pdb - 916/1000
# Succesfully saved x0915_ _cmap3.csv
# x0916.pdb - 917/1000
# Succesfully saved x0916_ _cmap3.csv
# x0917.pdb - 918/1000
# Succesfully saved x0917_ _cmap3.csv
# x0918.pdb - 919/1000
# Succesfully saved x0918_ _cmap3.csv
# x0919.pdb - 920/1000
# Succesfully saved x0919_ _cmap3.csv
# x0920.pdb - 921/1000
# Succesfully saved x0920_ _cmap3.csv
# x0921.pdb - 922/1000
# Succesfully saved x0921_ _cmap3.csv
# x0922.pdb - 923/1000
# Succesfully saved x0922_ _cmap3.csv
# x0923.pdb - 924/1000
# Succesfully saved x0923_ _cmap3.csv
# x0924.pdb - 925/1000
# Succesfully saved x0924_ _cmap3.csv
# x0925.pdb - 926/1000
# Succesfully saved x0925_ _cmap3.csv
# x0926.pdb - 927/1000
# Succesfully saved x0926_ _cmap3.csv
# x0927.pdb - 928/1000
# Succesfully saved x0927_ _cmap3.csv
# x0928.pdb - 929/1000
# Succesfully saved x0928_ _cmap3.csv
# x0929.pdb - 930/1000
# Succesfully saved x0929_ _cmap3.csv
# x0930.pdb - 931/1000
# Succesfully saved x0930_ _cmap3.csv
# x0931.pdb - 932/1000
# Succesfully saved x0931_ _cmap3.csv
# x0932.pdb - 933/1000
# Succesfully saved x0932_ _cmap3.csv
# x0933.pdb - 934/1000
# Succesfully saved x0933_ _cmap3.csv
# x0934.pdb - 935/1000
# Succesfully saved x0934_ _cmap3.csv
# x0935.pdb - 936/1000
# Succesfully saved x0935_ _cmap3.csv
# x0936.pdb - 937/1000
# Succesfully saved x0936_ _cmap3.csv
# x0937.pdb - 938/1000
# Succesfully saved x0937_ _cmap3.csv
# x0938.pdb - 939/1000
# Succesfully saved x0938_ _cmap3.csv
# x0939.pdb - 940/1000
# Succesfully saved x0939_ _cmap3.csv
# x0940.pdb - 941/1000
# Succesfully saved x0940_ _cmap3.csv
# x0941.pdb - 942/1000
# Succesfully saved x0941_ _cmap3.csv
# x0942.pdb - 943/1000
# Succesfully saved x0942_ _cmap3.csv
# x0943.pdb - 944/1000
# Succesfully saved x0943_ _cmap3.csv
# x0944.pdb - 945/1000
# Succesfully saved x0944_ _cmap3.csv
# x0945.pdb - 946/1000
# Succesfully saved x0945_ _cmap3.csv
# x0946.pdb - 947/1000
# Succesfully saved x0946_ _cmap3.csv
# x0947.pdb - 948/1000
# Succesfully saved x0947_ _cmap3.csv
# x0948.pdb - 949/1000
# Succesfully saved x0948_ _cmap3.csv
# x0949.pdb - 950/1000
# Succesfully saved x0949_ _cmap3.csv
# x0950.pdb - 951/1000
# Succesfully saved x0950_ _cmap3.csv
# x0951.pdb - 952/1000
# Succesfully saved x0951_ _cmap3.csv
# x0952.pdb - 953/1000
# Succesfully saved x0952_ _cmap3.csv
# x0953.pdb - 954/1000
# Succesfully saved x0953_ _cmap3.csv
# x0954.pdb - 955/1000
# Succesfully saved x0954_ _cmap3.csv
# x0955.pdb - 956/1000
# Succesfully saved x0955_ _cmap3.csv
# x0956.pdb - 957/1000
# Succesfully saved x0956_ _cmap3.csv
# x0957.pdb - 958/1000
# Succesfully saved x0957_ _cmap3.csv
# x0958.pdb - 959/1000
# Succesfully saved x0958_ _cmap3.csv
# x0959.pdb - 960/1000
# Succesfully saved x0959_ _cmap3.csv
# x0960.pdb - 961/1000
# Succesfully saved x0960_ _cmap3.csv
# x0961.pdb - 962/1000
# Succesfully saved x0961_ _cmap3.csv
# x0962.pdb - 963/1000
# Succesfully saved x0962_ _cmap3.csv
# x0963.pdb - 964/1000
# Succesfully saved x0963_ _cmap3.csv
# x0964.pdb - 965/1000
# Succesfully saved x0964_ _cmap3.csv
# x0965.pdb - 966/1000
# Succesfully saved x0965_ _cmap3.csv
# x0966.pdb - 967/1000
# Succesfully saved x0966_ _cmap3.csv
# x0967.pdb - 968/1000
# Succesfully saved x0967_ _cmap3.csv
# x0968.pdb - 969/1000
# Succesfully saved x0968_ _cmap3.csv
# x0969.pdb - 970/1000
# Succesfully saved x0969_ _cmap3.csv
# x0970.pdb - 971/1000
# Succesfully saved x0970_ _cmap3.csv
# x0971.pdb - 972/1000
# Succesfully saved x0971_ _cmap3.csv
# x0972.pdb - 973/1000
# Succesfully saved x0972_ _cmap3.csv
# x0973.pdb - 974/1000
# Succesfully saved x0973_ _cmap3.csv
# x0974.pdb - 975/1000
# Succesfully saved x0974_ _cmap3.csv
# x0975.pdb - 976/1000
# Succesfully saved x0975_ _cmap3.csv
# x0976.pdb - 977/1000
# Succesfully saved x0976_ _cmap3.csv
# x0977.pdb - 978/1000
# Succesfully saved x0977_ _cmap3.csv
# x0978.pdb - 979/1000
# Succesfully saved x0978_ _cmap3.csv
# x0979.pdb - 980/1000
# Succesfully saved x0979_ _cmap3.csv
# x0980.pdb - 981/1000
# Succesfully saved x0980_ _cmap3.csv
# x0981.pdb - 982/1000
# Succesfully saved x0981_ _cmap3.csv
# x0982.pdb - 983/1000
# Succesfully saved x0982_ _cmap3.csv
# x0983.pdb - 984/1000
# Succesfully saved x0983_ _cmap3.csv
# x0984.pdb - 985/1000
# Succesfully saved x0984_ _cmap3.csv
# x0985.pdb - 986/1000
# Succesfully saved x0985_ _cmap3.csv
# x0986.pdb - 987/1000
# Succesfully saved x0986_ _cmap3.csv
# x0987.pdb - 988/1000
# Succesfully saved x0987_ _cmap3.csv
# x0988.pdb - 989/1000
# Succesfully saved x0988_ _cmap3.csv
# x0989.pdb - 990/1000
# Succesfully saved x0989_ _cmap3.csv
# x0990.pdb - 991/1000
# Succesfully saved x0990_ _cmap3.csv
# x0991.pdb - 992/1000
# Succesfully saved x0991_ _cmap3.csv
# x0992.pdb - 993/1000
# Succesfully saved x0992_ _cmap3.csv
# x0993.pdb - 994/1000
# Succesfully saved x0993_ _cmap3.csv
# x0994.pdb - 995/1000
# Succesfully saved x0994_ _cmap3.csv
# x0995.pdb - 996/1000
# Succesfully saved x0995_ _cmap3.csv
# x0996.pdb - 997/1000
# Succesfully saved x0996_ _cmap3.csv
# x0997.pdb - 998/1000
# Succesfully saved x0997_ _cmap3.csv
# x0998.pdb - 999/1000
# Succesfully saved x0998_ _cmap3.csv
# x0999.pdb - 1000/1000
# Succesfully saved x0999_ _cmap3.csv
# Succesfully exported pscresults.csv

# %%
cmap_mat = np.zeros([len(numbering),len(numbering)],dtype='int')

for row in index:
        x = row[0]
        y = row[1]
        cmap_mat[x][y] = 1
        #cmap_mat[y][x] = 1
   

cmap_mat.shape

new_index=np.array(np.nonzero(cmap_mat))
new_index=np.transpose(new_index)
new_index

comparison = index == new_index
equal_arrays = comparison.all()
print(equal_arrays)
# Out:
# True

# %% [markdown]
# ### <center> Secondary structure tool </center>
# This function uses the STRIDE tool to calculate the protein's secondary structure. <br> ***NOTE*** STRIDE and DSSP agree in 95,4% of the cases, DSSP tends to assign shorter secondary structures. To use STRIDE files, download them from http://webclu.bio.wzw.tum.de/stride/ and put them in <code>input_files/STRIDE.
# </code>
# <br>https://en.wikipedia.org/wiki/STRIDE <br>
#
# It can be used to build a Sec. Struc - Sec. struc contact map, or filter out res-res contacts within a secondary structure.
#
# STRIDE
# * H - Alpha-Helix
# * B - Isolated Beta-Bridge
# * E - Beta Sheet
# * b - Isolated Beta-Bridge
# * G - 3-10 Helix
# * I - Pi helix
# * T - Turn
# * C - Coil
#
# The following function takes a STRIDE file as input an parses the secondary structure for further use.

# %%
structure, sequence = stride_secondary_struc('1bni.txt')

# %% [markdown]
# The following function uses the secondary structure to create a secondary structure-secondary structure based cmap (**cmap4**).<br> Note! It creates indices of the nonzero values in the contact map
# <br> Keep in mind that this function overwrites certain variables.

# %%
cmap4,segment = secondary_struc_cmap(
                                    chain,
                                    sequence,
                                    structure,
                                    cutoff_distance = 4.5,
                                    cutoff_numcontacts = 10,
                                    exclude_neighbour = 3,
                                    ss_elements = ['H','E','b','B','G'])

# %% [markdown]
# The following function transforms the indices into a cmap and exports it to <code>results/circuit_diagram</code>

# %%
export_cmap4(cmap4,segment,structure,protid)

# %% [markdown]
# This function takes in a res-res contact map and filters out contacts that are within specified secondary structures,<code>filtered_structures</code>.

# %%
cmap5,struc_id = secondary_struc_filter(
                                        index,
                                        structure,
                                        filtered_structures = ['H','E'])

# %% [markdown]
# ### <center> Circuit analysis </center>
#
# This function uses the circuit theory developed by Anatoly to calculate the amount of circuits within a certain protein. <br>
# <code>threshold</code> is the minimum length that will be included.

# %%
threshold = 12
segnums,meanlength,segends = string_pdb(index,numbering,threshold)

export_circuit([protid,segnums,meanlength,segends])

# %% [markdown]
# ### <center> Multi-chain analysis </center>

# %% [markdown]
# Circuit-topology of a whole model is also possible. This uses the same functions but with slightly different options. Keep in mind that it takes longer to compute due to the size of proteins. Import a PDB/CIF file like you normally would using <code>retrieve_chain()</code> and then use the following setting to obtain a contact map of the whole model.

# %%
index,numbering,protid,res_names = get_cmap(
                                            chain,
                                            level = 'model'
                                            cutoff_distance = cutoff_distance,
                                            cutoff_numcontacts = cutoff_numcontacts,        
                                            exclude_neighbour = exclude_neighbour)

# %% [markdown]
# The following function is the same, it automatically detects whether it is a model or chain cmap. It does output P,S,C,I,T,L instead of PSC however

# %%
mat,pscitl = get_matrix(index,protid)

# %% [markdown]
# The plotting functions also work, There is a different function for the topological matrix plot however.

# %%
circuit_plot(index,protid,numbering)
matrix_plot_model(mat,protid)
